# %% [markdown]
# Continuation of data exploration with the cleaned up data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

df = pd.read_pickle(r'C:\Users\alexa\Downloads\aug24_bds_int---co2\notebooks\AllEU30.pkl')

display(df.head())
# Out:
#                 ID Country                   Mh                 Tan  T    Va  \
# 2665338  3700529.0      FR  AUTOMOBILES PEUGEOT  e2*2007/46*0070*40  C  AHMR
# 2665354  3707627.0      FR  AUTOMOBILES PEUGEOT  e2*2007/46*0070*40  C  AHMR
# 2665373  3696204.0      FR  AUTOMOBILES PEUGEOT  e2*2007/46*0070*40  C  AHMR
# 2665374  3696214.0      FR  AUTOMOBILES PEUGEOT  e2*2007/46*0070*40  C  AHMR
# 2665382  3709072.0      FR  AUTOMOBILES PEUGEOT  e2*2007/46*0070*40  C  AHMR
#
#           Ve   Cn  Ct  Cr  ...  Ewltp (g/km)  W (mm)  At1 (mm)  At2 (mm)  \
# 2665338  P/S  208  M1  M1  ...         130.0  2538.0    1470.0    1470.0
# 2665354  P/S  208  M1  M1  ...         131.0  2538.0    1470.0    1470.0
# 2665373  P/S  208  M1  M1  ...         129.0  2538.0    1470.0    1470.0
# 2665374  P/S  208  M1  M1  ...         131.0  2538.0    1470.0    1470.0
# 2665382  P/S  208  M1  M1  ...         132.0  2538.0    1470.0    1470.0
#
#              Ft  Fm ec (cm3) ep (KW)  Status    year
# ...

# %% [markdown]
# Next steps:
#
# 1- Standardization of num variables
# 2- Encoding cat variables
#
# 3- Visualization num variables
# 4- Visualization cat variables

# %%
# Standardization of num variables

numerical_cols = AllEU30.select_dtypes(include=['float32', 'int64']).columns

scaler = StandardScaler()
AllEU30[numerical_cols] = scaler.fit_transform(AllEU30[numerical_cols])

# %%
# Encoding categorical variables / get_dummies do not work. Out of memory.
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#df['Categorical_Column'] = le.fit_transform(df['Categorical_Column'])
