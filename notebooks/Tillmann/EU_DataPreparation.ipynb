# %% [markdown]
# # Comments on what this notebook does:
#
# WARNING:
#
# For the script to work the data files must be positiong in the data path of the repository.
# Or the path to the data must be adapted accordingly. In this script all csv data must be in data_path
#
# # The data which is used here has received the following steps already
#
# * mapping of entries in countrys, and companies and so on, see Andreas jupyter notebooks
# * only unique values remains in columns which are categorical
#
# # The process steps which will be done in here:**
#
#  * Retrieving data
#  + Get an overview and count empty entries in the dataset
#  + Drop Fuel consumption because it is too much correlated with CO2 Emission
#  * Explanatory Variable is Ewltp (g/km) and Erwltp(g/km)
#  + Filter all data that has no explanatory variable
#  + Drop data before 2015 because of VW diesel Scandal
#  + Keep all contries, discuss why
#  + Search for unique Car Identification number to ommit double cars which have the same characterisics
#  + Discuss percentage error compared to the mean value for different car IDs: TAN, VFN, Ves
#  + Filter out Ve that are not combination from T & Va = Ve
#  + Filter out rows which have ? in their Ve
#
#  + Drop Columns which are not relevant: ID, r
#  + make separate DF with electric cars for separate research
#
#  + Save DF to csv

# %% [markdown]
# # Import Libraries

# %%
# First of all import the required libraries 
# Data and math  
import pandas as pd
import numpy as np 
import pyarrow.parquet as pq

# Visualisation 
import matplotlib.pyplot as plt  # für Matplotlib
import seaborn as sns            # für Seaborn
import plotly.express as px      # für Plotly Express
#%matplotlib inline

# Import System Libraries 
import warnings
import os
# Ignor all warnings, because there is a front problem with mach 
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Retrieving Data, deleting empty entries, Save dfs in callable variables

# %%
# Loading data from the combined French datasets

# Path to the neighboring 'data' folder
data_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data'))

# Check the path
print(data_path + '/EU_all_current_shared.parquet')

# Load parquet data
table = pq.read_table(os.path.join(data_path, 'EU_all_current_shared.parquet'))

# Convert to pandas DataFrame
df = table.to_pandas()

# Show the first few rows to confirm
print(df.head())
# Out:
# /Users/tillo/Repositoriums/aug24_bds_int---co2/data/EU_all_current_shared.parquet
#          ID Country  VFN              Mp              Mh  \
# 0  280060.0      UK  NaN             NaN         UNKNOWN
# 1  280060.0      UK  NaN             NaN         AUDI AG
# 2  280060.0      PL  NaN     VW GROUP PC      VOLKSWAGEN
# 3  280060.0      HU  NaN             NaN  HYUNDAI ASSAN
# 4  280060.0      HU  NaN  GENERAL MOTORS            OPEL
#
#                                 Man       MMS                  Tan  \
# 0                           UNKNOWN  VAUXHALL                  NaN
# 1                               NaN      AUDI                  NaN
# 2                     VOLKSWAGEN AG       NaN  e1*2001/116*0211*27
# 3  HYUNDAI ASSAN OTOMOTIV SANAYI VE   Hyundai  e11*2007/46*0192*04
# 4                      ADAM OPEL AG      Opel   e1*2007/46*0374*14
#
#              T       Va  ...  De  Vf Status    year Date of registration  \
# 0  A-H/MONOCAB     BF11  ... NaN NaN      P  2010.0                  NaN
# 1           B8  LCAKAQ1  ... NaN NaN      P  2011.0                  NaN
# 2           1T   CFHCAF  ... NaN NaN      P  2012.0                  NaN
# 3          ELH    F5D31  ... NaN NaN      P  2013.0                  NaN
# 4         0G-A  CAHBC12  ... NaN NaN      P  2014.0                  NaN
#
#    Fuel consumption   ech  RLFI  Electric range (km)  #identical occurences
# 0                NaN  NaN   NaN                  NaN                    1.0
# 1                NaN  NaN   NaN                  NaN                    1.0
# 2                NaN  NaN   NaN                  NaN                    1.0
# 3                NaN  NaN   NaN                  NaN                   30.0
# 4                NaN  NaN   NaN                  NaN                    1.0
#
# [5 rows x 41 columns]

# %% [markdown]
# # Filter for missing values (coming from andreas notebook)

# %%
def count_missing_values(df):
    missing_counts = {}
    
    for col in df.columns:
        # Count pd.NA and np.nan separately
        pd_na_count = df[col].isna().sum() if df[col].dtype.name == 'category' else 0
        np_nan_count = df[col].isna().sum() if df[col].dtype.name == 'float32' else 0
        
        # Store the results
        missing_counts[col] = {'pd.NA': pd_na_count,
                               'np.nan': np_nan_count,
                               'Dtype': df[col].dtype.name,
                               'Percent Missing': f"{df[col].isna().sum() / len(df[col]) * 100:.2f}%"
                              }

    # Convert the results to a DataFrame for easier viewing
    result_df = pd.DataFrame(missing_counts).T
    return result_df

# Count and display the missing values
result = count_missing_values(df)
print(result)
# Out:
#                           pd.NA    np.nan     Dtype Percent Missing
# ID                            0         0   float32           0.00%
# Country                       0         0  category           0.00%
# VFN                     6022343         0  category          41.70%
# Mp                      1538457         0  category          10.65%
# Mh                            0         0  category           0.00%
# Man                      310768         0  category           2.15%
# MMS                     6048284         0  category          41.88%
# Tan                      490543         0  category           3.40%
# T                         62037         0  category           0.43%
# Va                       100484         0  category           0.70%
# Ve                       225223         0  category           1.56%
# Mk                        42908         0  category           0.30%
# Cn                        49370         0  category           0.34%
# Ct                        24710         0  category           0.17%
# Cr                      2826753         0  category          19.57%
# r                             0         4   float32           0.00%
# m (kg)                        0     14075   float32           0.10%
# Mt                            0   3802983   float32          26.33%
# Enedc (g/km)                  0   5466691   float32          37.85%
# Ewltp (g/km)                  0   3565598   float32          24.69%
# W (mm)                        0   2252091   float32          15.59%
# At1 (mm)                      0   2523206   float32          17.47%
# At2 (mm)                      0   2738433   float32          18.96%
# Ft                        24373         0  category           0.17%
# Fm                        85880         0  category           0.59%
# ec (cm3)                      0    613895   float32           4.25%
# ep (KW)                       0   1401419   float32           9.70%
# z (Wh/km)                     0  13141566   float32          90.99%
# IT                      9564034         0  category          66.22%
# Ernedc (g/km)                 0  12638415   float32          87.51%
# Erwltp (g/km)                 0  11588146   float32          80.23%
# De                            0  14116055   float32          97.74%
# Vf                            0  13299530   float32          92.08%
# Status                        0         0  category           0.00%
# year                          0         0   float32           0.00%
# Date of registration    9206861         0  category          63.75%
# Fuel consumption              0  10470116   float32          72.49%
# ech                    13991213         0  category          96.87%
# RLFI                   13685744         0  category          94.76%
# Electric range (km)           0  13347797   float32          92.42%
# #identical occurences         0         0   float32           0.00%

# %% [markdown]
# # Drop fuel consumption

# %%
# Create a new DataFrame without the "Fuel consumption" column
df_new = df.drop(columns=['Fuel consumption '])

# %% [markdown]
# # Drop all data that does not contain target variable Ewltp (g/km)

# %%
# Delete all rows which have no informat on the target variable 
df_new2 = df_new.dropna(subset=['Ewltp (g/km)'], how='all')

df_new2.head()
df_new2.info()

# Count and display the missing values
print(count_missing_values(df_new2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10877194 entries, 2665338 to 14442791
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     float32
#  1   Country                category
#  2   VFN                    category
#  3   Mp                     category
#  4   Mh                     category
#  5   Man                    category
#  6   MMS                    category
#  7   Tan                    category
#  8   T                      category
#  9   Va                     category
#  10  Ve                     category
#  11  Mk                     category
#  12  Cn                     category
#  13  Ct                     category
#  14  Cr                     category
#  15  r                      float32
#  16  m (kg)                 float32
#  17  Mt                     float32
#  18  Enedc (g/km)           float32
#  19  Ewltp (g/km)           float32
#  20  W (mm)                 float32
#  21  At1 (mm)               float32
#  22  At2 (mm)               float32
#  23  Ft                     category
#  24  Fm                     category
#  25  ec (cm3)               float32
#  26  ep (KW)                float32
#  27  z (Wh/km)              float32
#  28  IT                     category
#  29  Ernedc (g/km)          float32
#  30  Erwltp (g/km)          float32
#  31  De                     float32
#  32  Vf                     float32
#  33  Status                 category
#  34  year                   float32
#  35  Date of registration   category
#  36  ech                    category
#  37  RLFI                   category
#  38  Electric range (km)    float32
#  39  #identical occurences  float32
# dtypes: category(21), float32(19)
# memory usage: 1.3 GB
#                           pd.NA    np.nan     Dtype Percent Missing
# ID                            0         0   float32           0.00%
# Country                       0         0  category           0.00%
# VFN                     2556651         0  category          23.50%
# Mp                       572856         0  category           5.27%
# Mh                            0         0  category           0.00%
# Man                           0         0  category           0.00%
# MMS                     5570688         0  category          51.21%
# Tan                       25050         0  category           0.23%
# T                          4295         0  category           0.04%
# Va                        26802         0  category           0.25%
# Ve                        84538         0  category           0.78%
# Mk                         2632         0  category           0.02%
# Cn                        32334         0  category           0.30%
# Ct                         2500         0  category           0.02%
# Cr                        48902         0  category           0.45%
# r                             0         0   float32           0.00%
# m (kg)                        0      3221   float32           0.03%
# Mt                            0    379945   float32           3.49%
# Enedc (g/km)                  0   5117522   float32          47.05%
# Ewltp (g/km)                  0         0   float32           0.00%
# W (mm)                        0   1812026   float32          16.66%
# At1 (mm)                      0   2052672   float32          18.87%
# At2 (mm)                      0   2057329   float32          18.91%
# Ft                          971         0  category           0.01%
# Fm                          645         0  category           0.01%
# ec (cm3)                      0    523230   float32           4.81%
# ep (KW)                       0    451696   float32           4.15%
# z (Wh/km)                     0   9607289   float32          88.33%
# IT                      6152746         0  category          56.57%
# Ernedc (g/km)                 0   9165225   float32          84.26%
# Erwltp (g/km)                 0   8045273   float32          73.96%
# De                            0  10561128   float32          97.09%
# Vf                            0   9789177   float32          90.00%
# Status                        0         0  category           0.00%
# year                          0         0   float32           0.00%
# Date of registration    5661566         0  category          52.05%
# ech                    10426194         0  category          95.85%
# RLFI                   10120697         0  category          93.05%
# Electric range (km)           0   9788521   float32          89.99%
# #identical occurences         0         0   float32           0.00%

# %% [markdown]
# # Drop data before 2015 because of VW diesel Scandal

# %%
# Filter for year 
# Filter rows where year is 2016 or greater
df_new3 = df_new2[df_new2['year'] >= 2016]

print('The shape of the remaining df:')
print(df_new3.shape)

df = df_new3
# Out:
# The shape of the remaining df:
# (10877194, 40)

# %% [markdown]
# # Keeping all contrys because of ratio, keep as much data as possible (even though we work for french car producer)

# %%
# Counting the entries per country
country_counts = df_new3['Country'].value_counts()

# The 5 most frequent countries and 'Other'
top_5 = country_counts.nlargest(5)
others = country_counts.sum() - top_5.sum()

# Prepare data for the chart
sizes = list(top_5) + [others]
labels = list(top_5.index) + ['Other']

# Colors for the chart
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#ff6666', '#c2c2f0']

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Ensures that pie is drawn as a circle
plt.title('Distribution of Countries in df_new3')

# Add legend
plt.legend(title="Countries", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.tight_layout()
plt.show()

# Output the total number of entries
print(f"Total number of entries: {len(df_new3)}")
# Out:
# Total number of entries: 10877194

# %% [markdown]
# # Drop all columns that might not be relevant for a technical description of a car:
#
# ID: Identification number.
# Country: Member state.
# Mp: Manufacturer pooling.
# Mh: Manufacturer name EU standard denomination.
# Man: Manufacturer name OEM declaration.
# MMS: Manufacturer name MS registry denomination.
# Cn: Commercial name.
# r: Total new registrations.
# Status: P = Provisional data, F = Final data.
# year: Reporting year.
# identical occurrences: Number of identical occurrences (duplicates + 1).

# %%
# List of non-technical columns to drop
non_technical_columns = [
    'ID', 
    'Country',  
    'Mp', 
    'Mh', 
    'Man', 
    'MMS', 
    'Cn', 
    'r', 
    'Status', 
    'year', 
    'Date of registration'
]

# Assuming df is your DataFrame
df = df.drop(columns=non_technical_columns)

# Display the cleaned DataFrame
print(df.head())
# Out:
#                          VFN                 Tan  T    Va   Ve       Mk  Ct  \
# 2665338  IP-02-VF3-2017-1310  e2*2007/46*0070*40  C  AHMR  P/S  PEUGEOT  M1
# 2665354  IP-02-VF3-2017-1310  e2*2007/46*0070*40  C  AHMR  P/S  PEUGEOT  M1
# 2665373  IP-02-VF3-2017-1310  e2*2007/46*0070*40  C  AHMR  P/S  PEUGEOT  M1
# 2665374  IP-02-VF3-2017-1310  e2*2007/46*0070*40  C  AHMR  P/S  PEUGEOT  M1
# 2665382  IP-02-VF3-2017-1310  e2*2007/46*0070*40  C  AHMR  P/S  PEUGEOT  M1
#
#          Cr  m (kg)      Mt  ...  z (Wh/km)   IT  Ernedc (g/km)  \
# 2665338  M1  1035.0  1177.0  ...        NaN  NaN            NaN
# 2665354  M1  1035.0  1183.0  ...        NaN  NaN            NaN
# 2665373  M1  1035.0  1166.0  ...        NaN  NaN            NaN
# 2665374  M1  1035.0  1180.0  ...        NaN  NaN            NaN
# 2665382  M1  1035.0  1192.0  ...        NaN  NaN            NaN
#
#          Erwltp (g/km)  De  Vf  ech  RLFI  Electric range (km)  \
# 2665338            NaN NaN NaN  NaN   NaN                  NaN
# 2665354            NaN NaN NaN  NaN   NaN                  NaN
# 2665373            NaN NaN NaN  NaN   NaN                  NaN
# 2665374            NaN NaN NaN  NaN   NaN                  NaN
# 2665382            NaN NaN NaN  NaN   NaN                  NaN
#
#          #identical occurences
# 2665338                    5.0
# 2665354                    1.0
# 2665373                    1.0
# 2665374                    1.0
# 2665382                    2.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Filter out all rows that have a ? in the Tan, Ve, VFN and delete the whole row

# %%
# Define a function that takes a DF and a column name and filteres for all entries with ? and deletes the rows
# Gives back filtered df 

def remove_rows_with_question_mark(df, column_name):
    # Find rows that contain a '?' in the specified column
    rows_with_question_mark = df[df[column_name].str.contains(r'\?', na=False)]
    
    # Drop these rows
    df_filtered_no_questionsmark = df.drop(rows_with_question_mark.index)

    print(f"Rows with '?' in any part of the string in column '{column_name}' have been removed.")
    
    # Return the filtered DataFrame
    return df_filtered_no_questionsmark

# %%
def clean_dataframe(df):
    # Remove rows with '?' from the specified columns
    df_cleaned = remove_rows_with_question_mark(df, 'Ve')
    df_cleaned = remove_rows_with_question_mark(df_cleaned, 'Tan')
    df_cleaned = remove_rows_with_question_mark(df_cleaned, 'VFN')
    
    return df_cleaned

# Example usage
# Assuming df is your original DataFrame
df_cleaned_of_questionsmarks = clean_dataframe(df)
# Out:
# Rows with '?' in any part of the string in column 'Ve' have been removed.
# Rows with '?' in any part of the string in column 'Tan' have been removed.
# Rows with '?' in any part of the string in column 'VFN' have been removed.

# %%
# Save the filtered DataFrame as a CSV file
df_cleaned_of_questionsmarks.to_csv(os.path.join(data_path, 'EU_NoQuestionmarks.csv'), index=False)

print("Shape of cleaned df from questionsmarks:", df_cleaned_of_questionsmarks.shape)
print("Filtered DataFrame has been saved as 'EU_NoQuestionmarks.csv' in the data_path.")
# Out:
# Shape of cleaned df from questionsmarks: (10659027, 29)
# Filtered DataFrame has been saved as 'EU_NoQuestionmarks.csv' in the data_path.

# %%
# Re identify the data frame 
df = df_cleaned_of_questionsmarks

# %% [markdown]
# # Searching for repeating car identification numbers in the data to delete possible repatings and therefore minimizing bias if a car appears very often

# %%
def find_top_10_most_frequent(df):
    # Find duplicate values in the 'Ve', 'Tan', and 'VFN' columns
    duplicate_values_Ve = df['Ve'][df['Ve'].duplicated()]
    duplicate_values_Tan = df['Tan'][df['Tan'].duplicated()]
    duplicate_values_VFN = df['VFN'][df['VFN'].duplicated()]

    # Count unique duplicate values for each column
    duplicate_counts_Ve = duplicate_values_Ve.value_counts()
    duplicate_counts_Tan = duplicate_values_Tan.value_counts()
    duplicate_counts_VFN = duplicate_values_VFN.value_counts()

    # Save the most frequent value for each column
    most_frequent_Ve = duplicate_counts_Ve.idxmax() if not duplicate_counts_Ve.empty else None
    most_frequent_Tan = duplicate_counts_Tan.idxmax() if not duplicate_counts_Tan.empty else None
    most_frequent_VFN = duplicate_counts_VFN.idxmax() if not duplicate_counts_VFN.empty else None

    # Get the top 10 most frequently appearing values
    top_10_Ve = duplicate_counts_Ve.head(10)
    top_10_Tan = duplicate_counts_Tan.head(10)
    top_10_VFN = duplicate_counts_VFN.head(10)

    return most_frequent_Ve, most_frequent_Tan, most_frequent_VFN, top_10_Ve, top_10_Tan, top_10_VFN, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN

# %%
most_frequent_Ve, most_frequent_Tan, most_frequent_VFN, top_10_Ve, top_10_Tan, top_10_VFN, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN = find_top_10_most_frequent(df)

# Display results
print("Most frequent 'Ve':", most_frequent_Ve)
print("Most frequent 'Tan':", most_frequent_Tan)
print("Most frequent 'VFN':", most_frequent_VFN)

print("\nTop 10 most frequent 'Ve':")
print(top_10_Ve)

print("\nTop 10 most frequent 'Tan':")
print(top_10_Tan)

print("\nTop 10 most frequent 'VFN':")
print(top_10_VFN)
# Out:
# Most frequent 'Ve': IAW50000
# Most frequent 'Tan': e1*2001/116*0480*41
# Most frequent 'VFN': IP-MQB37WZ_A0_0589-TMB-1
#
# Top 10 most frequent 'Ve':
# IAW50000    108013
# DAW50000     95284
# DAW500L0     84038
# IAW500L0     71662
# CZAA050A     71281
# FZAA150A     43749
# IAW500B0     43597
# JZAA150A     37842
# 6AW50000     37212
# HZAA150A     29583
# Name: Ve, dtype: int64
#
# Top 10 most frequent 'Tan':
# e1*2001/116*0480*41    26332
# e1*2001/116*0470*23    24697
# e1*2007/46*1909*19     24677
# e1*2007/46*1885*17     24351
# e1*2001/116*0220*53    23844
# e1*2007/46*2018*07     23656
# e1*2007/46*1909*17     23602
# e8*2007/46*0355*14     23202
# e13*2007/46*1911*06    22944
# e1*2007/46*1797*04     22839
# Name: Tan, dtype: int64
#
# Top 10 most frequent 'VFN':
# IP-MQB37WZ_A0_0589-TMB-1    26231
# IP-2018_1435-WDB-1          24029
# IP-MQB48ZZ_A1_0843-WVW-1    23809
# IP-MQB37AS_A3_0817-WVW-1    23658
# IP-0000529-WBA-1            22401
# IP-2018_1437-WDB-1          22182
# IP-MQB27SZ_A0_0539-TMB-1    22114
# IP-0000501-WBA-1            22055
# IP-MLB42AZ_B0_0688-WAU-1    19783
# IP-0000714-WBA-1            19413
# Name: VFN, dtype: int64

# %%
def calculate_percentage_error_10mostoftenappearing(df, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN):
    # Ve calculations for the 10 most frequent 'Ve'
    top_10_Ve = duplicate_counts_Ve.index[:10]  # Get the 10 most frequent 'Ve' values
    percentage_errors_Ve = []

    for ve_value in top_10_Ve:
        filtered_df_Ve = df[df['Ve'] == ve_value]
        mean_values_Ve = filtered_df_Ve.mean(numeric_only=True)
        numeric_df_Ve = filtered_df_Ve.select_dtypes(include=[np.number])
        rmse_values_Ve = np.sqrt(((numeric_df_Ve - mean_values_Ve) ** 2).mean())
        percentage_error_Ve = (rmse_values_Ve / mean_values_Ve) * 100
        percentage_errors_Ve.append(percentage_error_Ve)
        print(f"\nPercentage error relative to the mean for 'Ve' = {ve_value}: {percentage_error_Ve}")
    
    # Tan calculations for the 10 most frequent 'Tan'
    top_10_Tan = duplicate_counts_Tan.index[:10]  # Get the 10 most frequent 'Tan' values
    percentage_errors_Tan = []

    for tan_value in top_10_Tan:
        filtered_df_Tan = df[df['Tan'] == tan_value]
        mean_values_Tan = filtered_df_Tan.mean(numeric_only=True)
        numeric_df_Tan = filtered_df_Tan.select_dtypes(include=[np.number])
        rmse_values_Tan = np.sqrt(((numeric_df_Tan - mean_values_Tan) ** 2).mean())
        percentage_error_Tan = (rmse_values_Tan / mean_values_Tan) * 100
        percentage_errors_Tan.append(percentage_error_Tan)
        print(f"\nPercentage error relative to the mean for 'Tan' = {tan_value}: {percentage_error_Tan}")
    
    # VFN calculations for the 10 most frequent 'VFN'
    top_10_VFN = duplicate_counts_VFN.index[:10]  # Get the 10 most frequent 'VFN' values
    percentage_errors_VFN = []

    for vfn_value in top_10_VFN:
        filtered_df_VFN = df[df['VFN'] == vfn_value]
        mean_values_VFN = filtered_df_VFN.mean(numeric_only=True)
        numeric_df_VFN = filtered_df_VFN.select_dtypes(include=[np.number])
        rmse_values_VFN = np.sqrt(((numeric_df_VFN - mean_values_VFN) ** 2).mean())
        percentage_error_VFN = (rmse_values_VFN / mean_values_VFN) * 100
        percentage_errors_VFN.append(percentage_error_VFN)
        print(f"\nPercentage error relative to the mean for 'VFN' = {vfn_value}: {percentage_error_VFN}")
    
    return percentage_errors_Ve, percentage_errors_Tan, percentage_errors_VFN

# %%
def calculate_percentage_error(df, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN):
    # Ve calculations using the most frequent 'Ve'
    most_frequent_Ve = duplicate_counts_Ve.idxmax()  # Get the most frequent 'Ve'
    filtered_df_Ve = df[df['Ve'] == most_frequent_Ve]
    mean_values_Ve = filtered_df_Ve.mean(numeric_only=True)
    numeric_df_Ve = filtered_df_Ve.select_dtypes(include=[np.number])
    rmse_values_Ve = np.sqrt(((numeric_df_Ve - mean_values_Ve) ** 2).mean())
    percentage_error_Ve = (rmse_values_Ve / mean_values_Ve) * 100

    print(f"\nPercentage error relative to the mean for 'Ve': {percentage_error_Ve}")
    
    # Tan calculations using the most frequent 'Tan'
    most_frequent_Tan = duplicate_counts_Tan.idxmax()  # Get the most frequent 'Tan'
    filtered_df_Tan = df[df['Tan'] == most_frequent_Tan]
    mean_values_Tan = filtered_df_Tan.mean(numeric_only=True)
    numeric_df_Tan = filtered_df_Tan.select_dtypes(include=[np.number])
    rmse_values_Tan = np.sqrt(((numeric_df_Tan - mean_values_Tan) ** 2).mean())
    percentage_error_Tan = (rmse_values_Tan / mean_values_Tan) * 100

    print(f"\nPercentage error relative to the mean for 'Tan': {percentage_error_Tan}")
    
    # VFN calculations using the most frequent 'VFN'
    most_frequent_VFN = duplicate_counts_VFN.idxmax()  # Get the most frequent 'VFN'
    filtered_df_VFN = df[df['VFN'] == most_frequent_VFN]
    mean_values_VFN = filtered_df_VFN.mean(numeric_only=True)
    numeric_df_VFN = filtered_df_VFN.select_dtypes(include=[np.number])
    rmse_values_VFN = np.sqrt(((numeric_df_VFN - mean_values_VFN) ** 2).mean())
    percentage_error_VFN = (rmse_values_VFN / mean_values_VFN) * 100

    print(f"\nPercentage error relative to the mean for 'VFN': {percentage_error_VFN}")
    
    return percentage_error_Ve, percentage_error_Tan, percentage_error_VFN

# %%
percentage_error_Ve, percentage_error_Tan, percentage_error_VFN = calculate_percentage_error_10mostoftenappearing(df, 
                                                                                                                  duplicate_counts_Ve, duplicate_counts_Tan, 
                                                                                                                  duplicate_counts_VFN)
# Out:
# Percentage error relative to the mean for 'Ve' = IAW50000: m (kg)                    11.264828
# Mt                        11.142461
# Enedc (g/km)              51.344810
# Ewltp (g/km)              90.862381
# W (mm)                     4.807154
# At1 (mm)                   2.131854
# At2 (mm)                   2.535769
# ec (cm3)                  30.879038
# ep (KW)                   45.726414
# z (Wh/km)                 11.861824
# Ernedc (g/km)             27.217527
# Erwltp (g/km)             24.979265
# De                       211.073990
# Vf                              NaN
# Electric range (km)       26.400167
# #identical occurences    362.026825
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = DAW50000: m (kg)                    10.969784
# Mt                        11.061568
# Enedc (g/km)              37.550304
# Ewltp (g/km)              38.806324
# W (mm)                     5.396844
# At1 (mm)                   1.978980
# At2 (mm)                   2.259419
# ec (cm3)                  28.545544
# ep (KW)                   36.370232
# z (Wh/km)                 15.734035
# Ernedc (g/km)             37.177383
# Erwltp (g/km)             33.641739
# De                       775.309021
# Vf                       547.453918
# Electric range (km)       13.200320
# #identical occurences    400.046021
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = DAW500L0: m (kg)                    10.440825
# Mt                        10.074222
# Enedc (g/km)              14.049911
# Ewltp (g/km)              14.292108
# W (mm)                     5.115920
# At1 (mm)                   2.360925
# At2 (mm)                   2.853921
# ec (cm3)                  19.284769
# ep (KW)                   28.924244
# z (Wh/km)                 14.137066
# Ernedc (g/km)             50.518970
# Erwltp (g/km)             43.087822
# De                       855.183411
# Vf                       694.301392
# Electric range (km)        6.694286
# #identical occurences    350.635254
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = IAW500L0: m (kg)                      9.991007
# Mt                          9.792123
# Enedc (g/km)               22.384212
# Ewltp (g/km)               20.384892
# W (mm)                      3.284172
# At1 (mm)                    1.542708
# At2 (mm)                    1.800145
# ec (cm3)                   15.471718
# ep (KW)                    30.019072
# z (Wh/km)                   4.955997
# Ernedc (g/km)              17.101151
# Erwltp (g/km)              33.645813
# De                         71.969070
# Vf                       1596.015747
# Electric range (km)         5.363774
# #identical occurences     445.820892
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = CZAA050A: m (kg)                     10.338778
# Mt                          9.728998
# Enedc (g/km)               57.063396
# Ewltp (g/km)               63.950111
# W (mm)                      1.390339
# At1 (mm)                    1.616731
# At2 (mm)                    1.601874
# ec (cm3)                   24.634207
# ep (KW)                    37.300674
# z (Wh/km)                  15.535410
# Ernedc (g/km)              13.900447
# Erwltp (g/km)               0.000000
# De                       -218.410187
# Vf                       1284.502441
# Electric range (km)        44.035084
# #identical occurences     426.835388
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = FZAA150A: m (kg)                      4.203610
# Mt                          3.959235
# Enedc (g/km)                3.960481
# Ewltp (g/km)                5.887693
# W (mm)                      1.362510
# At1 (mm)                    1.731420
# At2 (mm)                    1.614125
# ec (cm3)                    0.402889
# ep (KW)                     9.453602
# z (Wh/km)                        NaN
# Ernedc (g/km)               2.478792
# Erwltp (g/km)               8.582851
# De                         39.867409
# Vf                       1683.250244
# Electric range (km)              NaN
# #identical occurences     473.861450
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = IAW500B0: m (kg)                     6.513993
# Mt                         6.680826
# Enedc (g/km)              11.329608
# Ewltp (g/km)               9.879601
# W (mm)                     2.920734
# At1 (mm)                   1.267107
# At2 (mm)                   1.617417
# ec (cm3)                  14.238811
# ep (KW)                   25.729111
# z (Wh/km)                  0.000000
# Ernedc (g/km)             29.244307
# Erwltp (g/km)             33.906940
# De                        68.711296
# Vf                              NaN
# Electric range (km)        0.000000
# #identical occurences    380.005768
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = JZAA150A: m (kg)                     3.455907
# Mt                         3.366680
# Enedc (g/km)              10.940307
# Ewltp (g/km)              11.017396
# W (mm)                     1.765874
# At1 (mm)                   1.028239
# At2 (mm)                   0.993180
# ec (cm3)                   7.850906
# ep (KW)                   24.568798
# z (Wh/km)                  0.000000
# Ernedc (g/km)              5.939077
# Erwltp (g/km)             10.162498
# De                      -105.208443
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    332.199982
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = 6AW50000: m (kg)                      7.548381
# Mt                          7.606261
# Enedc (g/km)               13.361865
# Ewltp (g/km)               10.952374
# W (mm)                      2.590478
# At1 (mm)                    0.701577
# At2 (mm)                    1.155135
# ec (cm3)                   22.068911
# ep (KW)                    29.138163
# z (Wh/km)                        NaN
# Ernedc (g/km)               5.555554
# Erwltp (g/km)                    NaN
# De                        390.756073
# Vf                       1553.500366
# Electric range (km)              NaN
# #identical occurences     358.657227
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = HZAA150A: m (kg)                      3.447859
# Mt                          3.310176
# Enedc (g/km)                8.608427
# Ewltp (g/km)                8.170132
# W (mm)                      0.234951
# At1 (mm)                    1.482127
# At2 (mm)                    1.413326
# ec (cm3)                    7.659136
# ep (KW)                    15.902927
# z (Wh/km)                        NaN
# Ernedc (g/km)               4.184386
# Erwltp (g/km)               8.767841
# De                        936.347961
# Vf                       4521.611328
# Electric range (km)              NaN
# #identical occurences     340.882477
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2001/116*0480*41: m (kg)                     9.654247
# Mt                         8.391013
# Enedc (g/km)             108.499168
# Ewltp (g/km)              65.051582
# W (mm)                     0.862123
# At1 (mm)                   1.454201
# At2 (mm)                   1.557356
# ec (cm3)                  18.595844
# ep (KW)                   31.282066
# z (Wh/km)                  9.811651
# Ernedc (g/km)              4.892560
# Erwltp (g/km)             13.500458
# De                              NaN
# Vf                              NaN
# Electric range (km)      126.637962
# #identical occurences    263.652924
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2001/116*0470*23: m (kg)                      4.270260
# Mt                          4.425986
# Enedc (g/km)                6.313464
# Ewltp (g/km)                5.993885
# W (mm)                      0.027776
# At1 (mm)                    0.623417
# At2 (mm)                    0.493806
# ec (cm3)                   13.789426
# ep (KW)                    24.537090
# z (Wh/km)                        NaN
# Ernedc (g/km)               6.708304
# Erwltp (g/km)               0.000000
# De                       1542.417969
# Vf                        703.258911
# Electric range (km)              NaN
# #identical occurences     748.412415
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2007/46*1909*19: m (kg)                     12.544641
# Mt                         11.564319
# Enedc (g/km)             2059.121338
# Ewltp (g/km)               84.236107
# W (mm)                      1.200029
# At1 (mm)                    0.626509
# At2 (mm)                    0.573827
# ec (cm3)                   18.948671
# ep (KW)                    27.232817
# z (Wh/km)                  10.616485
# Ernedc (g/km)                    NaN
# Erwltp (g/km)               9.122581
# De                               NaN
# Vf                               NaN
# Electric range (km)        54.575932
# #identical occurences     343.157593
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2007/46*1885*17: m (kg)                     6.909413
# Mt                         6.113149
# Enedc (g/km)              13.542358
# Ewltp (g/km)              71.849075
# W (mm)                     1.949669
# At1 (mm)                   1.455557
# At2 (mm)                   1.405343
# ec (cm3)                  26.020626
# ep (KW)                   39.574547
# z (Wh/km)                  7.182740
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              0.239083
# De                              NaN
# Vf                              NaN
# Electric range (km)        3.602427
# #identical occurences    217.707138
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2001/116*0220*53: m (kg)                     8.173468
# Mt                         6.013196
# Enedc (g/km)               8.714101
# Ewltp (g/km)               8.139859
# W (mm)                     4.985096
# At1 (mm)                   0.347126
# At2 (mm)                   0.345310
# ec (cm3)                   0.000000
# ep (KW)                   17.223185
# z (Wh/km)                       NaN
# Ernedc (g/km)              0.000000
# Erwltp (g/km)                   NaN
# De                       237.237167
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    357.075562
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2007/46*2018*07: m (kg)                     4.470971
# Mt                         4.400966
# Enedc (g/km)                    NaN
# Ewltp (g/km)               8.170330
# W (mm)                     0.042867
# At1 (mm)                   1.535708
# At2 (mm)                   1.528630
# ec (cm3)                  14.376417
# ep (KW)                   29.970512
# z (Wh/km)                       NaN
# Ernedc (g/km)                   NaN
# Erwltp (g/km)             11.532332
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    484.040771
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2007/46*1909*17: m (kg)                    12.188757
# Mt                        10.778358
# Enedc (g/km)             453.965179
# Ewltp (g/km)              80.198196
# W (mm)                     1.499920
# At1 (mm)                   1.359448
# At2 (mm)                   1.264988
# ec (cm3)                  18.997385
# ep (KW)                   25.706434
# z (Wh/km)                 10.396983
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              9.129323
# De                              NaN
# Vf                              NaN
# Electric range (km)       66.748253
# #identical occurences    242.362946
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e8*2007/46*0355*14: m (kg)                     6.121133
# Mt                         5.835714
# Enedc (g/km)               0.000000
# Ewltp (g/km)              20.269207
# W (mm)                     0.194431
# At1 (mm)                   0.261514
# At2 (mm)                   0.346471
# ec (cm3)                  16.339405
# ep (KW)                   24.445026
# z (Wh/km)                  2.538292
# Ernedc (g/km)                   NaN
# Erwltp (g/km)             10.205425
# De                              NaN
# Vf                              NaN
# Electric range (km)        4.029403
# #identical occurences    338.917053
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e13*2007/46*1911*06: m (kg)                      4.976207
# Mt                          4.750009
# Enedc (g/km)               11.762658
# Ewltp (g/km)                7.216789
# W (mm)                      0.000000
# At1 (mm)                    0.923702
# At2 (mm)                    0.900634
# ec (cm3)                   22.912106
# ep (KW)                    17.967051
# z (Wh/km)                   0.000000
# Ernedc (g/km)               8.453274
# Erwltp (g/km)              16.558153
# De                        238.396866
# Vf                       7811.386230
# Electric range (km)              NaN
# #identical occurences     696.458862
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e1*2007/46*1797*04: m (kg)                     2.914084
# Mt                         3.630086
# Enedc (g/km)              11.377258
# Ewltp (g/km)               9.590216
# W (mm)                     0.138923
# At1 (mm)                   1.602199
# At2 (mm)                   1.893061
# ec (cm3)                  19.394043
# ep (KW)                   25.011974
# z (Wh/km)                       NaN
# Ernedc (g/km)             23.030724
# Erwltp (g/km)             23.183826
# De                       153.098709
# Vf                       302.538330
# Electric range (km)             NaN
# #identical occurences    382.451782
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-MQB37WZ_A0_0589-TMB-1: m (kg)                     1.611870
# Mt                         2.114998
# Enedc (g/km)               8.914620
# Ewltp (g/km)               3.157722
# W (mm)                     0.420126
# At1 (mm)                   0.518022
# At2 (mm)                   0.552333
# ec (cm3)                   1.550436
# ep (KW)                    7.567225
# z (Wh/km)                  5.791665
# Ernedc (g/km)             23.932686
# Erwltp (g/km)              6.942689
# De                              NaN
# Vf                              NaN
# Electric range (km)       70.846786
# #identical occurences    268.099152
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2018_1435-WDB-1: m (kg)                     3.236548
# Mt                         3.108734
# Enedc (g/km)               3.247092
# Ewltp (g/km)               3.939731
# W (mm)                     1.093424
# At1 (mm)                   1.770624
# At2 (mm)                   1.693473
# ec (cm3)                   0.558002
# ep (KW)                    1.109346
# z (Wh/km)                       NaN
# Ernedc (g/km)              2.091534
# Erwltp (g/km)              4.502202
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    232.208710
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-MQB48ZZ_A1_0843-WVW-1: m (kg)                     2.314489
# Mt                         2.139493
# Enedc (g/km)               4.169446
# Ewltp (g/km)               2.147609
# W (mm)                     0.729937
# At1 (mm)                   0.586347
# At2 (mm)                   0.493653
# ec (cm3)                   1.124562
# ep (KW)                    3.765763
# z (Wh/km)                  0.000000
# Ernedc (g/km)             23.303928
# Erwltp (g/km)             29.554760
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    336.524048
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-MQB37AS_A3_0817-WVW-1: m (kg)                     2.476175
# Mt                         2.736254
# Enedc (g/km)               1.338613
# Ewltp (g/km)               2.324800
# W (mm)                     1.563959
# At1 (mm)                   0.379235
# At2 (mm)                   0.331736
# ec (cm3)                   0.405937
# ep (KW)                    3.074879
# z (Wh/km)                  0.000000
# Ernedc (g/km)             26.748243
# Erwltp (g/km)             27.949846
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    552.699829
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-0000529-WBA-1: m (kg)                     1.951817
# Mt                         2.333721
# Enedc (g/km)               3.220268
# Ewltp (g/km)               3.076462
# W (mm)                     0.200749
# At1 (mm)                   1.496960
# At2 (mm)                   1.492875
# ec (cm3)                   1.040806
# ep (KW)                    1.989931
# z (Wh/km)                       NaN
# Ernedc (g/km)             15.912353
# Erwltp (g/km)              6.029884
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    333.029572
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2018_1437-WDB-1: m (kg)                      2.962132
# Mt                          3.065227
# Enedc (g/km)                4.346469
# Ewltp (g/km)                4.278395
# W (mm)                      0.767239
# At1 (mm)                    1.714427
# At2 (mm)                    1.694829
# ec (cm3)                    3.107504
# ep (KW)                     5.353183
# z (Wh/km)                  19.469027
# Ernedc (g/km)               3.049580
# Erwltp (g/km)               8.262245
# De                          1.329515
# Vf                       1333.327637
# Electric range (km)              NaN
# #identical occurences     261.320129
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-MQB27SZ_A0_0539-TMB-1: m (kg)                     2.136703
# Mt                         2.325603
# Enedc (g/km)               6.613440
# Ewltp (g/km)               2.899353
# W (mm)                     0.494739
# At1 (mm)                   0.959771
# At2 (mm)                   0.874534
# ec (cm3)                   4.463595
# ep (KW)                   14.195230
# z (Wh/km)                  0.000000
# Ernedc (g/km)              6.459111
# Erwltp (g/km)              3.064939
# De                              NaN
# Vf                              NaN
# Electric range (km)        0.000000
# #identical occurences    334.939972
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-0000501-WBA-1: m (kg)                     0.932058
# Mt                         1.424362
# Enedc (g/km)              10.784302
# Ewltp (g/km)              63.977814
# W (mm)                     0.422799
# At1 (mm)                   0.448316
# At2 (mm)                   0.471939
# ec (cm3)                   0.710035
# ep (KW)                    9.806515
# z (Wh/km)                  2.932103
# Ernedc (g/km)              0.000010
# Erwltp (g/km)             11.684913
# De                              NaN
# Vf                              NaN
# Electric range (km)        6.023757
# #identical occurences    138.804321
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-MLB42AZ_B0_0688-WAU-1: m (kg)                     1.865417
# Mt                         2.381438
# Enedc (g/km)               1.788971
# Ewltp (g/km)               2.060745
# W (mm)                     0.303195
# At1 (mm)                   0.313932
# At2 (mm)                   0.296018
# ec (cm3)                   0.537838
# ep (KW)                    3.851857
# z (Wh/km)                  0.000000
# Ernedc (g/km)              0.000000
# Erwltp (g/km)              7.379603
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    328.050140
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-0000714-WBA-1: m (kg)                     0.134509
# Mt                         1.502594
# Enedc (g/km)               1.485188
# Ewltp (g/km)               2.983312
# W (mm)                     0.137606
# At1 (mm)                   1.470426
# At2 (mm)                   1.676745
# ec (cm3)                   0.028410
# ep (KW)                    3.210782
# z (Wh/km)                       NaN
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              7.195871
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    348.494781
# dtype: float32

# %%
# Out:
# <class 'str'>

# %% [markdown]
# # Filtering for Ve / TVV

# %%
text = """
We can see that the most appearing VFN has the least variance among the nummerical values. However in the next steps I will proove that there is small
flaw in the VE variable which I use to drastically shorten the data frame and end up with repeating Ves that occure onle 3000 times, but have a 0
percent variance among the nummerical values. 
"""

print(text)
# Out:
# We can see that the most appearing VFN has the least variance among the nummerical values. However in the next steps I will proove that there is small
# flaw in the VE variable which I use to drastically shorten the data frame and end up with repeating Ves that occure onle 3000 times, but have a 0
# percent variance among the nummerical values.

# %%
# Function to check if 'T' and 'Va' are contained in 'Ve'
def check_tva(row):
    t = str(row['T'])
    va = str(row['Va'])
    ve = str(row['Ve'])
    return t in ve and va in ve

# Apply the function and filter the DataFrame
df_filtered = df[df.apply(check_tva, axis=1)]

# Check the result
print(f"Original number of rows: {len(df)}")
print(f"Number of rows after filtering: {len(df_filtered)}")

# Display a few examples
print(df_filtered[['T', 'Va', 'Ve']].head())
# Out:
# Original number of rows: 10659027
# Number of rows after filtering: 271100
#          T    Va      Ve
# 2673316  U  UZA8  UZA8UC
# 2677175  U  UZ68  UZ68UC
# 2677276  U  UZ68  UZ68UC
# 2677371  U  UZA8  UZA8U4
# 2677377  U  UZA8  UZA8UC

# %%
most_frequent_Ve, most_frequent_Tan, most_frequent_VFN, top_10_Ve, top_10_Tan, top_10_VFN, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN = find_top_10_most_frequent(df_filtered)

# Display results
print("Most frequent 'Ve':", most_frequent_Ve)
print("Most frequent 'Tan':", most_frequent_Tan)
print("Most frequent 'VFN':", most_frequent_VFN)

print("\nTop 10 most frequent 'Ve':")
print(top_10_Ve)

print("\nTop 10 most frequent 'Tan':")
print(top_10_Tan)

print("\nTop 10 most frequent 'VFN':")
print(top_10_VFN)
# Out:
# Most frequent 'Ve': UZK5VC0
# Most frequent 'Tan': e9*2007/46*3146*06
# Most frequent 'VFN': IP-2020_256K2C-YV1-1
#
# Top 10 most frequent 'Ve':
# UZK5VC0        7293
# XZ15VD0        6105
# XZBBVF0        5074
# UZA8VD0        4083
# XZ72VD0        3768
# UZK5VD0        3760
# XZBWVF0        3752
# LFK2VC0        3593
# UZK9VD0        3440
# YHZJ-C2B000    3216
# Name: Ve, dtype: int64
#
# Top 10 most frequent 'Tan':
# e9*2007/46*3146*06    9858
# e4*2007/46*1220*04    8041
# e9*2007/46*3146*04    7752
# e4*2007/46*1220*03    6681
# e9*2007/46*3146*07    6371
# e4*2007/46*1220*06    6223
# e9*2007/46*3146*15    5782
# e4*2007/46*1315*08    5619
# e9*2007/46*3146*09    5479
# e9*2007/46*3146*08    5448
# Name: Tan, dtype: int64
#
# Top 10 most frequent 'VFN':
# IP-2020_256K2C-YV1-1        6435
# IP-2019_536BBF-YV1-1        6377
# IP-2019_53615D-YV1-1        6352
# IP-2020_246K5C-YV1-1        5733
# IP-2019_536BWF-YV1-1        4208
# IP-2020_246K5D-YV1-1        4073
# IP-2019_246K9D-YV1-1        3734
# IP-2019_256K2C-YV1-1        3563
# IP-YHZ____ATN83143-W0V-0    3420
# IP-2021_256H5D-YV1-1        3317
# Name: VFN, dtype: int64

# %%
percentage_error_Ve, percentage_error_Tan, percentage_error_VFN = calculate_percentage_error_10mostoftenappearing(df_filtered, 
                                                                                                                  duplicate_counts_Ve, duplicate_counts_Tan, 
                                                                                                                  duplicate_counts_VFN)
# Out:
# Percentage error relative to the mean for 'Ve' = UZK5VC0: m (kg)                     1.596140
# Mt                         1.692331
# Enedc (g/km)               1.725707
# Ewltp (g/km)               2.925365
# W (mm)                     0.201048
# At1 (mm)                   2.049440
# At2 (mm)                   2.069758
# ec (cm3)                   0.000000
# ep (KW)                    0.042115
# z (Wh/km)                       NaN
# Ernedc (g/km)              5.334348
# Erwltp (g/km)              2.683666
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    355.394318
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = XZ15VD0: m (kg)                     1.518726
# Mt                         1.541713
# Enedc (g/km)               1.260276
# Ewltp (g/km)               1.451720
# W (mm)                     0.818949
# At1 (mm)                   1.800020
# At2 (mm)                   1.762415
# ec (cm3)                   0.103840
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              1.876259
# Erwltp (g/km)             14.937110
# De                         0.000000
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    307.579773
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = XZBBVF0: m (kg)                     1.838403
# Mt                         1.481905
# Enedc (g/km)               0.909086
# Ewltp (g/km)              27.625057
# W (mm)                     0.000000
# At1 (mm)                   0.161810
# At2 (mm)                   0.190929
# ec (cm3)                   0.000000
# ep (KW)                    0.796126
# z (Wh/km)                  5.465952
# Ernedc (g/km)              0.000040
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)        6.903259
# #identical occurences    232.895081
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = UZA8VD0: m (kg)                     1.998946
# Mt                         2.470873
# Enedc (g/km)               3.204997
# Ewltp (g/km)               1.376194
# W (mm)                     0.001638
# At1 (mm)                   1.607401
# At2 (mm)                   1.684719
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              6.218313
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    209.777451
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = XZ72VD0: m (kg)                     1.617053
# Mt                         2.144112
# Enedc (g/km)               1.403836
# Ewltp (g/km)               1.065176
# W (mm)                     0.000603
# At1 (mm)                   0.409740
# At2 (mm)                   0.500833
# ec (cm3)                   0.183623
# ep (KW)                    1.150250
# z (Wh/km)                       NaN
# Ernedc (g/km)              0.000010
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    209.106323
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = UZK5VD0: m (kg)                     1.149447
# Mt                         1.412310
# Enedc (g/km)               4.838064
# Ewltp (g/km)               1.786268
# W (mm)                     0.166585
# At1 (mm)                   1.263159
# At2 (mm)                   1.255989
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              2.519457
# Erwltp (g/km)              4.019094
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    265.502716
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = XZBWVF0: m (kg)                     0.328515
# Mt                         1.232468
# Enedc (g/km)               0.534695
# Ewltp (g/km)              32.399178
# W (mm)                     0.000000
# At1 (mm)                   0.026998
# At2 (mm)                   0.028799
# ec (cm3)                   0.543621
# ep (KW)                    0.000000
# z (Wh/km)                  1.553525
# Ernedc (g/km)              0.000000
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# Electric range (km)        6.501860
# #identical occurences    370.574768
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = LFK2VC0: m (kg)                     1.132405
# Mt                         2.165359
# Enedc (g/km)               1.359700
# Ewltp (g/km)               3.560746
# W (mm)                     0.000000
# At1 (mm)                   1.199889
# At2 (mm)                   1.200770
# ec (cm3)                   0.000000
# ep (KW)                    0.136741
# z (Wh/km)                       NaN
# Ernedc (g/km)              5.703680
# Erwltp (g/km)              3.545550
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    294.371155
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = UZK9VD0: m (kg)                     1.005609
# Mt                         1.528622
# Enedc (g/km)               0.393106
# Ewltp (g/km)               3.058725
# W (mm)                     0.814517
# At1 (mm)                   2.113176
# At2 (mm)                   2.119405
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)             11.262524
# Erwltp (g/km)              8.427611
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    280.501495
# dtype: float32
#
# Percentage error relative to the mean for 'Ve' = YHZJ-C2B000: m (kg)                      2.352803
# Mt                          3.067869
# Enedc (g/km)                3.009024
# Ewltp (g/km)                2.488685
# W (mm)                      1.139025
# At1 (mm)                    1.536374
# At2 (mm)                    1.072780
# ec (cm3)                    0.000000
# ep (KW)                     0.277044
# z (Wh/km)                        NaN
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                        110.554146
# Vf                       1154.692749
# Electric range (km)              NaN
# #identical occurences     490.501343
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*06: m (kg)                     3.702325
# Mt                         4.258434
# Enedc (g/km)               8.544634
# Ewltp (g/km)               7.554671
# W (mm)                     0.085913
# At1 (mm)                   0.426504
# At2 (mm)                   0.056834
# ec (cm3)                  12.010281
# ep (KW)                   13.844840
# z (Wh/km)                       NaN
# Ernedc (g/km)             14.142135
# Erwltp (g/km)                   NaN
# De                       108.785652
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    295.666840
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*04: m (kg)                     6.574452
# Mt                         5.709662
# Enedc (g/km)              24.986679
# Ewltp (g/km)              21.299801
# W (mm)                     0.066186
# At1 (mm)                   2.034166
# At2 (mm)                   2.083864
# ec (cm3)                   0.000000
# ep (KW)                   20.435070
# z (Wh/km)                  4.860182
# Ernedc (g/km)                   NaN
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# Electric range (km)        0.000000
# #identical occurences    273.750000
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*04: m (kg)                      3.947871
# Mt                          4.806892
# Enedc (g/km)                9.352477
# Ewltp (g/km)                7.901096
# W (mm)                      0.000420
# At1 (mm)                    0.030713
# At2 (mm)                    0.000000
# ec (cm3)                    9.215815
# ep (KW)                    15.579891
# z (Wh/km)                        NaN
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                         91.938576
# Vf                       3077.410400
# Electric range (km)              NaN
# #identical occurences     210.991760
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*03: m (kg)                      6.038632
# Mt                          5.468648
# Enedc (g/km)               22.637054
# Ewltp (g/km)               18.468628
# W (mm)                      0.005242
# At1 (mm)                    0.481885
# At2 (mm)                    0.510042
# ec (cm3)                    0.000000
# ep (KW)                    20.073233
# z (Wh/km)                  10.392953
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                          0.000000
# Vf                       3143.721924
# Electric range (km)         0.000000
# #identical occurences     250.259323
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*07: m (kg)                     4.575077
# Mt                         4.698985
# Enedc (g/km)              29.053289
# Ewltp (g/km)              27.986330
# W (mm)                     0.000000
# At1 (mm)                   0.608207
# At2 (mm)                   0.780477
# ec (cm3)                  13.716912
# ep (KW)                   12.069951
# z (Wh/km)                  8.538327
# Ernedc (g/km)              0.000129
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)        5.676418
# #identical occurences    326.744141
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*06: m (kg)                     7.415646
# Mt                         6.335542
# Enedc (g/km)              31.395638
# Ewltp (g/km)              28.028048
# W (mm)                     0.002062
# At1 (mm)                   2.008429
# At2 (mm)                   2.078032
# ec (cm3)                   0.000000
# ep (KW)                   21.988638
# z (Wh/km)                  3.496089
# Ernedc (g/km)              6.928201
# Erwltp (g/km)                   NaN
# De                       134.715057
# Vf                              NaN
# Electric range (km)        4.795757
# #identical occurences    414.647827
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*15: m (kg)                     9.776067
# Mt                         9.185340
# Enedc (g/km)             138.883347
# Ewltp (g/km)              70.307632
# W (mm)                     0.000000
# At1 (mm)                   1.366845
# At2 (mm)                   1.483059
# ec (cm3)                  14.423476
# ep (KW)                   34.498219
# z (Wh/km)                 24.007730
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              2.555172
# De                              NaN
# Vf                              NaN
# Electric range (km)       93.705276
# #identical occurences    331.160156
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1315*08: m (kg)                     7.384497
# Mt                         6.994235
# Enedc (g/km)              37.254490
# Ewltp (g/km)              35.644096
# W (mm)                     0.718261
# At1 (mm)                   0.884679
# At2 (mm)                   0.896644
# ec (cm3)                   0.000000
# ep (KW)                   25.585382
# z (Wh/km)                  2.914957
# Ernedc (g/km)              0.000040
# Erwltp (g/km)                   NaN
# De                        44.561241
# Vf                              NaN
# Electric range (km)        2.824532
# #identical occurences    246.857208
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*09: m (kg)                     7.252668
# Mt                         7.143572
# Enedc (g/km)              58.825123
# Ewltp (g/km)              48.523514
# W (mm)                     0.001500
# At1 (mm)                   0.208261
# At2 (mm)                   0.309107
# ec (cm3)                  12.478744
# ep (KW)                   24.233692
# z (Wh/km)                 16.214849
# Ernedc (g/km)             18.398279
# Erwltp (g/km)             14.046370
# De                         0.000000
# Vf                              NaN
# Electric range (km)      120.803726
# #identical occurences    373.018372
# dtype: float32
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*08: m (kg)                     5.362829
# Mt                         5.228052
# Enedc (g/km)              38.831738
# Ewltp (g/km)              36.719864
# W (mm)                     0.000000
# At1 (mm)                   0.113150
# At2 (mm)                   0.131527
# ec (cm3)                  14.406860
# ep (KW)                   13.639384
# z (Wh/km)                  6.571511
# Ernedc (g/km)              0.000109
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)        5.608517
# #identical occurences    302.824463
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2020_256K2C-YV1-1: m (kg)                     2.496415
# Mt                         2.869751
# Enedc (g/km)               2.788101
# Ewltp (g/km)               4.012601
# W (mm)                     2.520199
# At1 (mm)                   1.127022
# At2 (mm)                   1.124989
# ec (cm3)                   0.311434
# ep (KW)                    0.716011
# z (Wh/km)                  0.000000
# Ernedc (g/km)              4.005936
# Erwltp (g/km)              3.482468
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    289.233246
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2019_536BBF-YV1-1: m (kg)                     2.420514
# Mt                         2.116059
# Enedc (g/km)               4.532383
# Ewltp (g/km)              30.586620
# W (mm)                     0.115908
# At1 (mm)                   0.163492
# At2 (mm)                   0.191980
# ec (cm3)                   0.591730
# ep (KW)                    1.837381
# z (Wh/km)                  5.818920
# Ernedc (g/km)              0.000040
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# Electric range (km)       69.139252
# #identical occurences    233.766800
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2019_53615D-YV1-1: m (kg)                     1.885784
# Mt                         1.970619
# Enedc (g/km)               2.591096
# Ewltp (g/km)               2.466763
# W (mm)                     0.879948
# At1 (mm)                   1.762808
# At2 (mm)                   1.734671
# ec (cm3)                   2.282915
# ep (KW)                    2.309413
# z (Wh/km)                 27.083334
# Ernedc (g/km)              0.000407
# Erwltp (g/km)             14.841649
# De                       109.090912
# Vf                              NaN
# Electric range (km)        0.000000
# #identical occurences    306.626434
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2020_246K5C-YV1-1: m (kg)                     1.646366
# Mt                         1.799797
# Enedc (g/km)               2.877254
# Ewltp (g/km)               3.006066
# W (mm)                     0.298350
# At1 (mm)                   2.052800
# At2 (mm)                   2.053948
# ec (cm3)                   0.329943
# ep (KW)                    0.857276
# z (Wh/km)                  0.000000
# Ernedc (g/km)              4.794850
# Erwltp (g/km)              2.713423
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    350.058167
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2019_536BWF-YV1-1: m (kg)                     1.274566
# Mt                         1.648963
# Enedc (g/km)               1.885921
# Ewltp (g/km)              43.449635
# W (mm)                     0.000000
# At1 (mm)                   0.025652
# At2 (mm)                   0.027363
# ec (cm3)                   5.887879
# ep (KW)                    4.682238
# z (Wh/km)                  1.567057
# Ernedc (g/km)              0.000000
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# Electric range (km)        6.397609
# #identical occurences    370.055664
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2020_246K5D-YV1-1: m (kg)                     1.104895
# Mt                         1.419964
# Enedc (g/km)               4.645006
# Ewltp (g/km)               1.908790
# W (mm)                     0.158086
# At1 (mm)                   1.213411
# At2 (mm)                   1.208477
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              2.687918
# Erwltp (g/km)              3.969319
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    268.699982
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2019_246K9D-YV1-1: m (kg)                     0.990591
# Mt                         1.560200
# Enedc (g/km)               1.158921
# Ewltp (g/km)               3.108633
# W (mm)                     0.776941
# At1 (mm)                   2.093913
# At2 (mm)                   2.101725
# ec (cm3)                   0.000000
# ep (KW)                    0.505599
# z (Wh/km)                       NaN
# Ernedc (g/km)             10.790144
# Erwltp (g/km)              8.150100
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    282.117188
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2019_256K2C-YV1-1: m (kg)                     2.319990
# Mt                         2.288807
# Enedc (g/km)               1.940676
# Ewltp (g/km)               3.109466
# W (mm)                     0.169681
# At1 (mm)                   0.650578
# At2 (mm)                   0.595843
# ec (cm3)                   0.418523
# ep (KW)                    0.542825
# z (Wh/km)                  0.000000
# Ernedc (g/km)              0.000040
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    277.639526
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-YHZ____ATN83143-W0V-0: m (kg)                     0.915721
# Mt                         1.375601
# Enedc (g/km)              10.635990
# Ewltp (g/km)               2.869508
# W (mm)                     0.015824
# At1 (mm)                   0.509961
# At2 (mm)                   0.697360
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)             31.304386
# Erwltp (g/km)             33.628429
# De                              NaN
# Vf                              NaN
# Electric range (km)             NaN
# #identical occurences    398.325958
# dtype: float32
#
# Percentage error relative to the mean for 'VFN' = IP-2021_256H5D-YV1-1: m (kg)                     0.641902
# Mt                         1.320284
# Enedc (g/km)               2.777657
# Ewltp (g/km)              87.413239
# W (mm)                     0.000000
# At1 (mm)                   0.256949
# At2 (mm)                   0.259653
# ec (cm3)                   0.000000
# ep (KW)                    0.592157
# z (Wh/km)                  4.296068
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              0.000000
# De                              NaN
# Vf                              NaN
# Electric range (km)        8.714983
# #identical occurences    192.626328
# dtype: float32

# %% [markdown]
# # Group by TVV and calculate average and RMSE for each nummeric column

# %%
# Print the columns of your DataFrame
print(df_filtered.columns)
df_filtered.head()
# Out:
# Index(['VFN', 'Tan', 'T', 'Va', 'Ve', 'Mk', 'Ct', 'Cr', 'm (kg)', 'Mt',
#        'Enedc (g/km)', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft',
#        'Fm', 'ec (cm3)', 'ep (KW)', 'z (Wh/km)', 'IT', 'Ernedc (g/km)',
#        'Erwltp (g/km)', 'De', 'Vf', 'ech', 'RLFI', 'Electric range (km)',
#        '#identical occurences'],
#       dtype='object')
#          VFN              Tan  T    Va      Ve     Mk  Ct  Cr  m (kg)      Mt  \
# 2673316  NaN  e4*2007/46*1220  U  UZA8  UZA8UC  VOLVO  M1  M1  1866.0  2051.0
# 2677175  NaN  e4*2007/46*1220  U  UZ68  UZ68UC  VOLVO  M1  M1  1901.0  2141.0
# 2677276  NaN  e4*2007/46*1220  U  UZ68  UZ68UC  VOLVO  M1  M1  1901.0  2042.0
# 2677371  NaN  e4*2007/46*1220  U  UZA8  UZA8U4  VOLVO  M1  M1  1815.0  1940.0
# 2677377  NaN  e4*2007/46*1220  U  UZA8  UZA8UC  VOLVO  M1  M1  1866.0  2008.0
#
#          ...  z (Wh/km)   IT  Ernedc (g/km)  Erwltp (g/km)  De  Vf  ech  RLFI  \
# 2673316  ...        NaN  NaN            NaN            NaN NaN NaN  NaN   NaN
# 2677175  ...        NaN  NaN            NaN            NaN NaN NaN  NaN   NaN
# 2677276  ...        NaN  NaN            NaN            NaN NaN NaN  NaN   NaN
# 2677371  ...        NaN  NaN            NaN            NaN NaN NaN  NaN   NaN
# 2677377  ...        NaN  NaN            NaN            NaN NaN NaN  NaN   NaN
#
#          Electric range (km)  #identical occurences
# 2673316                  NaN                    1.0
# 2677175                  NaN                    1.0
# 2677276                  NaN                    1.0
# 2677371                  NaN                    1.0
# 2677377                  NaN                    1.0
#
# [5 rows x 29 columns]

# %%
# Group of columns I want to average: 
""""
m (kg): Mass in running order (weight of the vehicle).
Mt: WLTP test mass.
Enedc (g/km): Specific CO2 emissions (NEDC test).
Ewltp (g/km): Specific CO2 emissions (WLTP test).
W (mm): Wheelbase (length between the front and rear axles).
At1 (mm): Axle width (steering axle).
At2 (mm): Axle width (other axle).
ep (KW): Engine power (in kilowatts).
ec (cm3): Engine capacity (in cubic centimeters).
Electric range (km): Electric range of the vehicle.
z (Wh/km): Electric energy consumption (energy used per distance).
Ernedc (g/km): Emissions reduction through innovative technologies (NEDC).
Erwltp (g/km): Emissions reduction through innovative technologies (WLTP).
""""

# %%
list_columns_avg = 'm (kg)', 'Mt', 'Ewltp', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'ep (KW)', 'ec (cm3)', 'Electric range (km)', 'z (Wh/km)', 'Erwltp (g/km)'

# %%
def combine_by_Ve_custom(df, list_columns_avg):
    """
    Combine rows in the DataFrame based on the same 'Ve' value,
    calculating the average and RMSE for specified columns
    and the mode for all other columns.

    Parameters:
    df (pd.DataFrame): Input DataFrame with a 'Ve' column.
    list_columns_avg (list): List of column names for which to calculate averages and RMSE.

    Returns:
    pd.DataFrame: A new DataFrame with combined rows, averages, RMSE, and modes.
    """
    
    # Identify columns that are not in list_columns_avg for mode aggregation
    other_columns = df.columns.difference(list_columns_avg + ['Ve'])
    
    # Prepare a dictionary for aggregation
    agg_dict = {
        col: ['mean', lambda x: np.sqrt(((x - x.mean()) ** 2).mean())] for col in list_columns_avg
    }
    
    # Add mode aggregation for other columns
    for col in other_columns:
        agg_dict[col] = lambda x: x.mode()[0]  # Get the most frequent value

    # Group by 'Ve' and aggregate
    grouped_df = df.groupby('Ve').agg(agg_dict).reset_index()

    # Rename columns to include suffixes
    for col in list_columns_avg:
        grouped_df.rename(columns={col: f"{col}_avg"}, inplace=True)
        grouped_df.rename(columns={col: f"{col}_RMSE"}, inplace=True)

    return grouped_df

# Example usage
# Assuming your DataFrame is named df and contains the specified columns
list_columns_avg = [
    'm (kg)', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 
    'At2 (mm)', 'ep (KW)', 'ec (cm3)', 'Electric range (km)', 
    'z (Wh/km)', 'Erwltp (g/km)'
]

result_df = combine_by_Ve_custom(df_filtered, list_columns_avg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:287, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286 try:
# --> 287     return self._python_agg_general(func, *args, **kwargs)
#     288 except KeyError:
#     289     # TODO: KeyError is raised in _python_agg_general,
#     290     #  see test_groupby.test_basic
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._python_agg_general(self, func, *args, **kwargs)
#    1488 try:
#    1489     # if this function is invalid for this dtype, we will ignore it.
# -> 1490     result = self.grouper.agg_series(obj, f)
#    1491 except TypeError:
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/ops.py:981, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     980 else:
# --> 981     result = self._aggregate_series_pure_python(obj, func)
#     983 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1005, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1004 group = group.__finalize__(obj, method="groupby")
# -> 1005 res = func(group)
#    1006 res = libreduction.extract_result(res)
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1476, in GroupBy._python_agg_general.<locals>.<lambda>(x)
#    1475 func = com.is_builtin_func(func)
# -> 1476 f = lambda x: func(x, *args, **kwargs)
#    1478 # iterate through "columns" ex exclusions to populate output dict
#
# Cell In[44], line 25, in combine_by_Ve_custom.<locals>.<lambda>(x)
#      24 for col in other_columns:
# ---> 25     agg_dict[col] = lambda x: x.mode()[0]  # Get the most frequent value
#      27 # Group by 'Ve' and aggregate
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 45
#      37 # Example usage
#      38 # Assuming your DataFrame is named df and contains the specified columns
#      39 list_columns_avg = [
#      40     'm (kg)', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)',
#      41     'At2 (mm)', 'ep (KW)', 'ec (cm3)', 'Electric range (km)',
#      42     'z (Wh/km)', 'Erwltp (g/km)'
#      43 ]
# ---> 45 result_df = combine_by_Ve_custom(df_filtered, list_columns_avg)
#
# Cell In[44], line 28, in combine_by_Ve_custom(df, list_columns_avg)
#      25     agg_dict[col] = lambda x: x.mode()[0]  # Get the most frequent value
#      27 # Group by 'Ve' and aggregate
# ---> 28 grouped_df = df.groupby('Ve').agg(agg_dict).reset_index()
#      30 # Rename columns to include suffixes
#      31 for col in list_columns_avg:
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/apply.py:481, in Apply.agg_dict_like(self)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
# --> 481     results = {
#     482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/apply.py:482, in <dictcomp>(.0)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
#     481     results = {
# --> 482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:271, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
# --> 271     ret = self._aggregate_multiple_funcs(func)
#     272     if relabeling:
#     273         # error: Incompatible types in assignment (expression has type
#     274         # "Optional[List[str]]", variable has type "Index")
#     275         ret.columns = columns  # type: ignore[assignment]
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:326, in SeriesGroupBy._aggregate_multiple_funcs(self, arg)
#     323 for idx, (name, func) in enumerate(arg):
#     325     key = base.OutputKey(label=name, position=idx)
# --> 326     results[key] = self.aggregate(func)
#     328 if any(isinstance(x, DataFrame) for x in results.values()):
#     329     from pandas import concat
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:291, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     287     return self._python_agg_general(func, *args, **kwargs)
#     288 except KeyError:
#     289     # TODO: KeyError is raised in _python_agg_general,
#     290     #  see test_groupby.test_basic
# --> 291     result = self._aggregate_named(func, *args, **kwargs)
#     293     # result is a dict whose keys are the elements of result_index
#     294     index = self.grouper.result_index
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/groupby/generic.py:415, in SeriesGroupBy._aggregate_named(self, func, *args, **kwargs)
#     412 for name, group in self:
#     413     object.__setattr__(group, "name", name)
# --> 415     output = func(group, *args, **kwargs)
#     416     output = libreduction.extract_result(output)
#     417     if not initialized:
#     418         # We only do this validation on the first iteration
#
# Cell In[44], line 25, in combine_by_Ve_custom.<locals>.<lambda>(x)
#      23 # Add mode aggregation for other columns
#      24 for col in other_columns:
# ---> 25     agg_dict[col] = lambda x: x.mode()[0]  # Get the most frequent value
#      27 # Group by 'Ve' and aggregate
#      28 grouped_df = df.groupby('Ve').agg(agg_dict).reset_index()
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 0

# %%
# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(os.path.join(data_path, 'EU_Tv_Filtered.csv'), index=False)

print("Filtered DataFrame has been saved as 'EU_Tv_Filtered.csv' in the data_path.")

# %%
# Load the DataFrame from the file path
df_filtered_Tv = pd.read_csv(os.path.join(data_path, 'EU_Tv_Filtered.csv'))

# %% [markdown]
# # I am going for VFN, it has the lowest error rate

# %%
print(type(most_frequent_VFN))


# List of the 10 most frequent VFNs
most_frequent_VFN_10 = [
    'IP-MQB37WZ_A0_0589-TMB-1',
    'IP-2018_1435-WDB-1',
    'IP-MQB48ZZ_A1_0843-WVW-1',
    'IP-MQB37AS_A3_0817-WVW-1',
    'IP-0000529-WBA-1',
    'IP-2018_1437-WDB-1',
    'IP-MQB27SZ_A0_0539-TMB-1',
    'IP-0000501-WBA-1',
    'IP-MLB42AZ_B0_0688-WAU-1',
    'IP-0000714-WBA-1'
]

# %%
# Initialize a dictionary to store results
results = {}

# Loop through each most frequent VFN
for vfn in most_frequent_VFN_10:
    # Filter the DataFrame to get rows with the current VFN
    filtered_df = df[df['VFN'] == vfn]

    # Count occurrences of TANs for the current VFN
    tan_counts = filtered_df['Tan'].value_counts().nlargest(5)  # Get top 5 TANs

    # Store the results
    results[vfn] = tan_counts

# Print the results
for vfn, tan_counts in results.items():
    print(f"Top 5 TANs for VFN {vfn}:")
    print(tan_counts)
    print()
# Out:
# Top 5 TANs for VFN IP-MQB37WZ_A0_0589-TMB-1:
# e8*2007/46*0355*14    4170
# e8*2007/46*0355*10    3459
# e8*2007/46*0355*15    3070
# e8*2007/46*0355*09    3051
# e8*2007/46*0355*06    2595
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-2018_1435-WDB-1:
# e1*2007/46*1829*06    1229
# e1*2007/46*1829*12    1164
# e1*2007/46*1912*19    1096
# e1*2007/46*1912*18    1048
# e1*2007/46*1912*08     982
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-MQB48ZZ_A1_0843-WVW-1:
# e1*2001/116*0307*69    2369
# e1*2001/116*0307*74    2283
# e1*2001/116*0307*72    2207
# e1*2001/116*0307*70    2057
# e1*2001/116*0307*75    2044
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-MQB37AS_A3_0817-WVW-1:
# e1*2001/116*0450*64    2336
# e1*2001/116*0450*70    2320
# e1*2001/116*0450*63    2200
# e1*2001/116*0450*62    2162
# e1*2001/116*0450*67    2051
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-0000529-WBA-1:
# e1*2007/46*2018*07    5691
# e1*2007/46*2018*06    3120
# e1*2007/46*2018*03    2981
# e1*2007/46*2018*04    2450
# e1*2007/46*2064*07    2192
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-2018_1437-WDB-1:
# e1*2007/46*1829*12    1209
# e1*2007/46*1829*14    1152
# e1*2007/46*1829*13    1152
# e1*2007/46*1829*16     849
# e1*2007/46*1829*10     830
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-MQB27SZ_A0_0539-TMB-1:
# e8*2007/46*0349*17    3811
# e8*2007/46*0349*15    3182
# e8*2007/46*0349*14    2861
# e8*2007/46*0349*11    2635
# e8*2007/46*0349*10    2433
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-0000501-WBA-1:
# e1*2007/46*1918*14    6970
# e1*2007/46*1918*13    5209
# e1*2007/46*1918*09    3585
# e1*2007/46*1918*10    2848
# e1*2007/46*1918*11    1933
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-MLB42AZ_B0_0688-WAU-1:
# e1*2007/46*1550*39    3547
# e1*2007/46*1550*28    2289
# e1*2007/46*1550*38    2096
# e1*2007/46*1550*32    1654
# e1*2007/46*1550*22    1312
# Name: Tan, dtype: int64
#
# Top 5 TANs for VFN IP-0000714-WBA-1:
# e1*2007/46*1797*15    4819
# e1*2007/46*1881*11    2849
# e1*2007/46*1797*12    2757
# e1*2007/46*1797*13    1973
# e1*2007/46*1797*14    1944
# Name: Tan, dtype: int64

# %% [markdown]
# # Clean all outlier rows of the duplicate Ves
#
# # This should only concern the outliers of the feature variables, not the target! and we only use some feature variables
#
# # This need to be addapted better

# %%
def remove_outliers_from_duplicates(df, column_name):
    # Finde die duplizierten Werte in der angegebenen Spalte
    duplicate_values = df[column_name][df[column_name].duplicated()]
    duplicate_counts = duplicate_values.value_counts()

    # Erstelle ein leeres DataFrame für die gefilterten Ergebnisse
    df_filtered = pd.DataFrame()

    # Iteriere über die duplizierten Werte
    for value in duplicate_counts.index:
        # Filtere die Zeilen, die den aktuellen duplizierten Wert enthalten
        duplicate_rows = df[df[column_name] == value]

        # Berechne den IQR für die numerischen Spalten
        numeric_columns = duplicate_rows.select_dtypes(include=[float, int]).columns
        Q1 = duplicate_rows[numeric_columns].quantile(0.25)
        Q3 = duplicate_rows[numeric_columns].quantile(0.75)
        IQR = Q3 - Q1

        # Bestimme die Grenzen für Ausreißer
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Finde die Zeilen, die keine Ausreißer sind
        is_outlier = (duplicate_rows[numeric_columns] < lower_bound) | (duplicate_rows[numeric_columns] > upper_bound)
        non_outlier_rows = duplicate_rows[~is_outlier.any(axis=1)]

        # Füge die nicht ausreißenden Zeilen dem gefilterten DataFrame hinzu
        df_filtered = pd.concat([df_filtered, non_outlier_rows], ignore_index=True)

    print(f"Ausreißer aus den Duplikaten in der Spalte '{column_name}' wurden entfernt.")
    
    # Rückgabe des gefilterten DataFrames
    return df_filtered

# %%
# Beispielnutzung
# Angenommen, df ist dein ursprüngliches DataFrame
df_cleaned_outliers = remove_outliers_from_duplicates(df_cleaned_of_questionsmarks, 'Ve')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 3
#       1 # Beispielnutzung
#       2 # Angenommen, df ist dein ursprüngliches DataFrame
# ----> 3 df_cleaned_outliers = remove_outliers_from_duplicates(df_cleaned_of_questionsmarks, 'Ve')
#
# Cell In[39], line 29, in remove_outliers_from_duplicates(df, column_name)
#      26     non_outlier_rows = duplicate_rows[~is_outlier.any(axis=1)]
#      28     # Füge die nicht ausreißenden Zeilen dem gefilterten DataFrame hinzu
# ---> 29     df_filtered = pd.concat([df_filtered, non_outlier_rows], ignore_index=True)
#      31 print(f"Ausreißer aus den Duplikaten in der Spalte '{column_name}' wurden entfernt.")
#      33 # Rückgabe des gefilterten DataFrames
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/reshape/concat.py:595, in _Concatenator.get_result(self)
#     591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
# --> 595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#     598 if not self.copy:
#     599     new_data._consolidate_inplace()
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/internals/concat.py:242, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     240     fastpath = blk.values.dtype == values.dtype
#     241 else:
# --> 242     values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     243     fastpath = False
#     245 if fastpath:
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/internals/concat.py:583, in _concatenate_join_units(join_units, concat_axis, copy)
#     580     concat_values = ensure_block_shape(concat_values, 2)
#     582 else:
# --> 583     concat_values = concat_compat(to_concat, axis=concat_axis)
#     585 return concat_values
#
# File ~/opt/anaconda3/envs/Project_DS_CO2/lib/python3.9/site-packages/pandas/core/dtypes/concat.py:151, in concat_compat(to_concat, axis, ea_compat_axis)
#     148             to_concat = [x.astype("object") for x in to_concat]
#     149             kinds = {"o"}
# --> 151 result = np.concatenate(to_concat, axis=axis)
#     152 if "b" in kinds and result.dtype.kind in ["i", "u", "f"]:
#     153     # GH#39817
#     154     warnings.warn(
#     155         "Behavior when concatenating bool-dtype and numeric-dtype arrays is "
#     156         "deprecated; in a future version these will cast to object dtype "
#    (...)
#     160         stacklevel=find_stack_level(),
#     161     )
#
# KeyboardInterrupt:

# %%
# Save the filtered DataFrame as a CSV file
df_cleaned_outliers.to_csv(os.path.join(data_path, 'EU_Ve_OutliersCleaned.csv'), index=False)
print("Shape of cleaned df from questionsmarks:", df_cleaned_outliers.shape)
print("Filtered DataFrame has been saved as 'EU_NoQuestionmarks.csv' in the data_path.")

# %%
# Now find again the most often appearing values and do again a search for the percentage error of the remaining df_filtered_Tv

# %%
most_frequent_Ve, most_frequent_Tan, most_frequent_VFN, top_10_Ve, top_10_Tan, top_10_VFN, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN = find_top_10_most_frequent(df_filtered_Tv)


# Display results
print("Most frequent 'Ve':", most_frequent_Ve)
print("Most frequent 'Tan':", most_frequent_Tan)
print("Most frequent 'VFN':", most_frequent_VFN)

print("\nTop 10 most frequent 'Ve':")
print(top_10_Ve)

print("\nTop 10 most frequent 'Tan':")
print(top_10_Tan)

print("\nTop 10 most frequent 'VFN':")
print(top_10_VFN)
# Out:
# Most frequent 'Ve': UZK5VC0?
# Most frequent 'Tan': e9*2007/46*3146*06
# Most frequent 'VFN': IP-2020_246K5C-YV1-1
#
# Top 10 most frequent 'Ve':
# UZK5VC0?    8019
# UZK5VC0     7293
# XZ15VD0     6105
# XZBBVF0     5074
# XZ15VD0?    4861
# XZBBVF0?    4839
# UZH1VD0?    4443
# UZA8VD0     4083
# XZBWVF0?    3912
# XZ72VD0     3768
# Name: Ve, dtype: int64
#
# Top 10 most frequent 'Tan':
# e9*2007/46*3146*06    15205
# e4*2007/46*1220*04    12281
# e4*2007/46*1315*08    12166
# e9*2007/46*3146*04    12063
# e9*2007/46*3146*15    12005
# e4*2007/46*1220*17    10674
# e9*2007/46*3146*07    10568
# e9*2007/46*3146*09    10105
# e4*2007/46*1220*03     9815
# e4*2007/46*1220*06     9766
# Name: Tan, dtype: int64
#
# Top 10 most frequent 'VFN':
# IP-2020_246K5C-YV1-1    11175
# IP-2019_536BBF-YV1-1    11171
# IP-2019_53615D-YV1-1    10617
# IP-2020_256K2C-YV1-1     9891
# IP-2019_536BWF-YV1-1     7967
# IP-2021_246H1D-YV1-1     7249
# IP-2020_246K5D-YV1-1     6159
# IP-2019_536L4D-YV1-1     5976
# IP-2021_256H5D-YV1-1     5802
# IP-2019_246K9D-YV1-1     5623
# Name: VFN, dtype: int64

# %%
percentage_error_Ve, percentage_error_Tan, percentage_error_VFN = calculate_percentage_error_10mostoftenappearing(df_filtered_Tv, duplicate_counts_Ve, duplicate_counts_Tan, duplicate_counts_VFN)
# Out:
# Percentage error relative to the mean for 'Ve' = UZK5VC0?: ID                        80.024459
# r                          0.000000
# m (kg)                     1.582903
# Mt                         1.786811
# Enedc (g/km)               1.905135
# Ewltp (g/km)               2.849370
# W (mm)                     0.853698
# At1 (mm)                   2.191846
# At2 (mm)                   2.203917
# ec (cm3)                   0.000000
# ep (KW)                    4.153804
# z (Wh/km)                       NaN
# Ernedc (g/km)              3.379381
# Erwltp (g/km)              1.942535
# De                              NaN
# Vf                              NaN
# year                       0.062975
# Electric range (km)             NaN
# #identical occurences    252.007491
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = UZK5VC0: ID                        78.016510
# r                          0.000000
# m (kg)                     1.596219
# Mt                         1.692333
# Enedc (g/km)               1.725711
# Ewltp (g/km)               2.925357
# W (mm)                     0.201043
# At1 (mm)                   2.049457
# At2 (mm)                   2.069758
# ec (cm3)                   0.000000
# ep (KW)                    0.042118
# z (Wh/km)                       NaN
# Ernedc (g/km)              5.334361
# Erwltp (g/km)              2.683669
# De                              NaN
# Vf                              NaN
# year                       0.063710
# Electric range (km)             NaN
# #identical occurences    355.403762
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZ15VD0: ID                        85.294697
# r                          0.000000
# m (kg)                     1.518715
# Mt                         1.541718
# Enedc (g/km)               1.260277
# Ewltp (g/km)               1.451708
# W (mm)                     0.818955
# At1 (mm)                   1.800031
# At2 (mm)                   1.762414
# ec (cm3)                   0.103843
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              1.876254
# Erwltp (g/km)             14.937150
# De                         0.000000
# Vf                              NaN
# year                       0.045149
# Electric range (km)             NaN
# #identical occurences    307.587453
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZBBVF0: ID                       8.087249e+01
# r                        0.000000e+00
# m (kg)                   1.838348e+00
# Mt                       1.481905e+00
# Enedc (g/km)             9.090774e-01
# Ewltp (g/km)             2.762512e+01
# W (mm)                   0.000000e+00
# At1 (mm)                 1.618082e-01
# At2 (mm)                 1.909240e-01
# ec (cm3)                 0.000000e+00
# ep (KW)                  7.961433e-01
# z (Wh/km)                5.465957e+00
# Ernedc (g/km)            7.401487e-14
# Erwltp (g/km)                     NaN
# De                       0.000000e+00
# Vf                                NaN
# year                     4.840805e-02
# Electric range (km)      6.903237e+00
# #identical occurences    2.328967e+02
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZ15VD0?: ID                       9.072168e+01
# r                        0.000000e+00
# m (kg)                   1.434044e+00
# Mt                       1.847603e+00
# Enedc (g/km)             2.023218e-01
# Ewltp (g/km)             2.233960e+00
# W (mm)                   5.854268e-01
# At1 (mm)                 1.883176e+00
# At2 (mm)                 1.839674e+00
# ec (cm3)                 0.000000e+00
# ep (KW)                  2.295363e+00
# z (Wh/km)                         NaN
# Ernedc (g/km)            3.145632e-13
# Erwltp (g/km)            1.850372e-14
# De                       1.581139e+02
# Vf                                NaN
# year                     4.742147e-02
# Electric range (km)               NaN
# #identical occurences    3.245272e+02
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZBBVF0?: ID                        77.380827
# r                          0.000000
# m (kg)                     1.237800
# Mt                         1.490053
# Enedc (g/km)               8.498707
# Ewltp (g/km)              20.800291
# W (mm)                     0.982794
# At1 (mm)                   0.561067
# At2 (mm)                   0.543025
# ec (cm3)                   0.000000
# ep (KW)                   26.408965
# z (Wh/km)                  3.392677
# Ernedc (g/km)                   NaN
# Erwltp (g/km)             19.075145
# De                        40.824829
# Vf                              NaN
# year                       0.050064
# Electric range (km)        7.677958
# #identical occurences    329.111312
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = UZH1VD0?: ID                        22.298451
# r                          0.000000
# m (kg)                     0.662437
# Mt                         1.091049
# Enedc (g/km)               2.020305
# Ewltp (g/km)              92.100261
# W (mm)                     0.060764
# At1 (mm)                   1.552571
# At2 (mm)                   1.549518
# ec (cm3)                   0.000000
# ep (KW)                    3.740961
# z (Wh/km)                  6.144053
# Ernedc (g/km)                   NaN
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# year                       0.026454
# Electric range (km)        4.469349
# #identical occurences    330.518264
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = UZA8VD0: ID                        75.182643
# r                          0.000000
# m (kg)                     1.998927
# Mt                         2.470872
# Enedc (g/km)               3.204947
# Ewltp (g/km)               1.376192
# W (mm)                     0.001638
# At1 (mm)                   1.607419
# At2 (mm)                   1.684731
# ec (cm3)                   0.000000
# ep (KW)                    0.000000
# z (Wh/km)                       NaN
# Ernedc (g/km)              6.218316
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# year                       0.033292
# Electric range (km)             NaN
# #identical occurences    209.777750
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZBWVF0?: ID                        52.093427
# r                          0.000000
# m (kg)                     0.152960
# Mt                         1.097833
# Enedc (g/km)               0.970666
# Ewltp (g/km)              13.439907
# W (mm)                     0.033429
# At1 (mm)                   0.046384
# At2 (mm)                   0.117933
# ec (cm3)                   0.000000
# ep (KW)                   12.645907
# z (Wh/km)                  3.028954
# Ernedc (g/km)                   NaN
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# year                       0.044801
# Electric range (km)        6.780524
# #identical occurences    282.814522
# dtype: float64
#
# Percentage error relative to the mean for 'Ve' = XZ72VD0: ID                       116.141499
# r                          0.000000
# m (kg)                     1.617051
# Mt                         2.144110
# Enedc (g/km)               1.403825
# Ewltp (g/km)               1.065173
# W (mm)                     0.000603
# At1 (mm)                   0.409742
# At2 (mm)                   0.500836
# ec (cm3)                   0.183622
# ep (KW)                    1.150269
# z (Wh/km)                       NaN
# Ernedc (g/km)              0.000000
# Erwltp (g/km)                   NaN
# De                         0.000000
# Vf                              NaN
# year                       0.040806
# Electric range (km)             NaN
# #identical occurences    209.105521
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*06: ID                         75.937056
# r                           0.000000
# m (kg)                      3.538897
# Mt                          4.144643
# Enedc (g/km)                8.232267
# Ewltp (g/km)                7.224512
# W (mm)                      0.071721
# At1 (mm)                    0.350675
# At2 (mm)                    0.080927
# ec (cm3)                   12.520361
# ep (KW)                    13.402822
# z (Wh/km)                   1.257862
# Ernedc (g/km)              11.134044
# Erwltp (g/km)                    NaN
# De                        150.584650
# Vf                       4237.924020
# year                        0.018029
# Electric range (km)         0.000000
# #identical occurences     292.849078
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*04: ID                         65.457628
# r                           0.000000
# m (kg)                      6.675000
# Mt                          5.894600
# Enedc (g/km)               27.418851
# Ewltp (g/km)               23.976640
# W (mm)                      0.062286
# At1 (mm)                    2.440693
# At2 (mm)                    2.498283
# ec (cm3)                    0.000000
# ep (KW)                    22.131418
# z (Wh/km)                   4.164962
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                               NaN
# Vf                       2991.655060
# year                        0.020388
# Electric range (km)         8.883251
# #identical occurences     293.298547
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1315*08: ID                       8.183123e+01
# r                        0.000000e+00
# m (kg)                   7.473507e+00
# Mt                       6.998221e+00
# Enedc (g/km)             3.868325e+01
# Ewltp (g/km)             3.778346e+01
# W (mm)                   6.853810e-01
# At1 (mm)                 9.876078e-01
# At2 (mm)                 8.102314e-01
# ec (cm3)                 0.000000e+00
# ep (KW)                  2.652210e+01
# z (Wh/km)                3.469477e+00
# Ernedc (g/km)            1.480297e-13
# Erwltp (g/km)                     NaN
# De                       4.336407e+01
# Vf                                NaN
# year                     2.137835e-02
# Electric range (km)      8.472626e+00
# #identical occurences    2.733367e+02
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*04: ID                         50.790130
# r                           0.000000
# m (kg)                      3.745824
# Mt                          4.520665
# Enedc (g/km)                9.036571
# Ewltp (g/km)                7.616702
# W (mm)                      0.018362
# At1 (mm)                    0.029152
# At2 (mm)                    0.061001
# ec (cm3)                    9.149372
# ep (KW)                    15.202047
# z (Wh/km)                        NaN
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                         91.938580
# Vf                       3315.493930
# year                        0.023851
# Electric range (km)              NaN
# #identical occurences     197.581253
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*15: ID                        23.401635
# r                          0.000000
# m (kg)                    10.374381
# Mt                         9.808989
# Enedc (g/km)             132.340796
# Ewltp (g/km)              88.542785
# W (mm)                     0.021185
# At1 (mm)                   1.302617
# At2 (mm)                   1.424737
# ec (cm3)                  14.414565
# ep (KW)                   38.970337
# z (Wh/km)                 18.820822
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              2.643684
# De                              NaN
# Vf                              NaN
# year                       0.024648
# Electric range (km)       77.733426
# #identical occurences    415.373799
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*17: ID                        23.524301
# r                          0.000000
# m (kg)                     5.598557
# Mt                         5.835968
# Enedc (g/km)               2.093581
# Ewltp (g/km)              68.883900
# W (mm)                     0.584821
# At1 (mm)                   2.649804
# At2 (mm)                   2.646351
# ec (cm3)                   0.000000
# ep (KW)                   18.340012
# z (Wh/km)                  7.081350
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              6.137447
# De                              NaN
# Vf                              NaN
# year                       0.024719
# Electric range (km)        6.161205
# #identical occurences    322.439593
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*07: ID                       7.205303e+01
# r                        0.000000e+00
# m (kg)                   4.552790e+00
# Mt                       4.810587e+00
# Enedc (g/km)             3.095502e+01
# Ewltp (g/km)             3.009681e+01
# W (mm)                   8.772150e-01
# At1 (mm)                 8.297297e-01
# At2 (mm)                 9.224060e-01
# ec (cm3)                 1.400650e+01
# ep (KW)                  1.709198e+01
# z (Wh/km)                5.991000e+00
# Ernedc (g/km)            1.850372e-14
# Erwltp (g/km)                     NaN
# De                       3.651484e+01
# Vf                                NaN
# year                     1.744597e-02
# Electric range (km)      7.037539e+00
# #identical occurences    3.424472e+02
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e9*2007/46*3146*09: ID                        79.436246
# r                          0.000000
# m (kg)                     8.253530
# Mt                         8.040210
# Enedc (g/km)              63.517016
# Ewltp (g/km)              51.666830
# W (mm)                     0.406010
# At1 (mm)                   0.784103
# At2 (mm)                   0.806730
# ec (cm3)                  12.779105
# ep (KW)                   29.755544
# z (Wh/km)                 19.685870
# Ernedc (g/km)             19.979514
# Erwltp (g/km)             15.172414
# De                       141.421356
# Vf                              NaN
# year                       0.025181
# Electric range (km)      128.655042
# #identical occurences    470.893509
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*03: ID                         44.791489
# r                           1.009175
# m (kg)                      6.336256
# Mt                          5.756746
# Enedc (g/km)               25.772111
# Ewltp (g/km)               21.201273
# W (mm)                      0.069473
# At1 (mm)                    0.493873
# At2 (mm)                    0.517679
# ec (cm3)                    0.000000
# ep (KW)                    20.759389
# z (Wh/km)                  10.655670
# Ernedc (g/km)                    NaN
# Erwltp (g/km)                    NaN
# De                          0.000000
# Vf                       3457.841330
# year                        0.017583
# Electric range (km)         1.449275
# #identical occurences     515.080610
# dtype: float64
#
# Percentage error relative to the mean for 'Tan' = e4*2007/46*1220*06: ID                        76.894050
# r                          0.000000
# m (kg)                     7.188602
# Mt                         6.145495
# Enedc (g/km)              31.540663
# Ewltp (g/km)              28.998714
# W (mm)                     0.031392
# At1 (mm)                   2.424762
# At2 (mm)                   2.506421
# ec (cm3)                   0.000000
# ep (KW)                   21.719665
# z (Wh/km)                  4.179905
# Ernedc (g/km)              6.928203
# Erwltp (g/km)                   NaN
# De                       123.377038
# Vf                              NaN
# year                       0.021528
# Electric range (km)       14.252251
# #identical occurences    374.182851
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2020_246K5C-YV1-1: ID                        52.122582
# r                          0.000000
# m (kg)                     1.644286
# Mt                         1.897383
# Enedc (g/km)               2.017541
# Ewltp (g/km)               3.279495
# W (mm)                     0.789865
# At1 (mm)                   2.205634
# At2 (mm)                   2.202790
# ec (cm3)                   0.236356
# ep (KW)                    3.532138
# z (Wh/km)                 40.169757
# Ernedc (g/km)              3.611408
# Erwltp (g/km)              2.351423
# De                              NaN
# Vf                              NaN
# year                       0.046814
# Electric range (km)        0.000000
# #identical occurences    338.501365
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2019_536BBF-YV1-1: ID                       8.249593e+01
# r                        0.000000e+00
# m (kg)                   1.960231e+00
# Mt                       1.901376e+00
# Enedc (g/km)             3.785200e+00
# Ewltp (g/km)             2.687077e+01
# W (mm)                   6.437997e-01
# At1 (mm)                 4.205965e-01
# At2 (mm)                 4.263795e-01
# ec (cm3)                 4.465047e-01
# ep (KW)                  1.934582e+01
# z (Wh/km)                4.847128e+00
# Ernedc (g/km)            9.251859e-14
# Erwltp (g/km)            0.000000e+00
# De                       3.015113e+01
# Vf                                NaN
# year                     4.825962e-02
# Electric range (km)      5.398062e+01
# #identical occurences    2.432275e+02
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2019_53615D-YV1-1: ID                       8.327461e+01
# r                        0.000000e+00
# m (kg)                   1.749080e+00
# Mt                       1.915270e+00
# Enedc (g/km)             2.094428e+00
# Ewltp (g/km)             2.485453e+00
# W (mm)                   7.879235e-01
# At1 (mm)                 1.870391e+00
# At2 (mm)                 1.834137e+00
# ec (cm3)                 1.909179e+00
# ep (KW)                  1.882787e+00
# z (Wh/km)                2.708333e+01
# Ernedc (g/km)            7.216450e-13
# Erwltp (g/km)            1.481240e+01
# De                       1.401058e+02
# Vf                                NaN
# year                     4.385978e-02
# Electric range (km)      0.000000e+00
# #identical occurences    3.184024e+02
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2020_256K2C-YV1-1: ID                        50.910945
# r                          0.000000
# m (kg)                     2.330780
# Mt                         3.068900
# Enedc (g/km)               2.311362
# Ewltp (g/km)               4.192789
# W (mm)                     2.039722
# At1 (mm)                   1.281541
# At2 (mm)                   1.278707
# ec (cm3)                   0.251227
# ep (KW)                    4.450147
# z (Wh/km)                 10.416667
# Ernedc (g/km)              3.876948
# Erwltp (g/km)              3.746980
# De                              NaN
# Vf                              NaN
# year                       0.046676
# Electric range (km)        0.000000
# #identical occurences    300.390559
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2019_536BWF-YV1-1: ID                        51.375548
# r                          0.000000
# m (kg)                     0.934065
# Mt                         1.447643
# Enedc (g/km)               2.123535
# Ewltp (g/km)              34.718022
# W (mm)                     0.026746
# At1 (mm)                   0.040232
# At2 (mm)                   0.095839
# ec (cm3)                   4.335902
# ep (KW)                    9.745676
# z (Wh/km)                  2.439802
# Ernedc (g/km)              0.000000
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# year                       0.044988
# Electric range (km)        7.439316
# #identical occurences    356.091805
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2021_246H1D-YV1-1: ID                        23.886309
# r                          0.000000
# m (kg)                     0.481008
# Mt                         1.120835
# Enedc (g/km)               2.854555
# Ewltp (g/km)              98.608791
# W (mm)                     0.051664
# At1 (mm)                   1.352472
# At2 (mm)                   1.350064
# ec (cm3)                   0.000000
# ep (KW)                    2.104449
# z (Wh/km)                  7.165751
# Ernedc (g/km)                   NaN
# Erwltp (g/km)                   NaN
# De                              NaN
# Vf                              NaN
# year                       0.026330
# Electric range (km)        7.006558
# #identical occurences    319.994202
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2020_246K5D-YV1-1: ID                        46.867702
# r                          0.000000
# m (kg)                     1.432693
# Mt                         1.535114
# Enedc (g/km)               5.281282
# Ewltp (g/km)               2.904516
# W (mm)                     0.127810
# At1 (mm)                   1.983855
# At2 (mm)                   1.975483
# ec (cm3)                   0.000000
# ep (KW)                    0.932254
# z (Wh/km)                  0.000000
# Ernedc (g/km)              2.846806
# Erwltp (g/km)              3.878672
# De                              NaN
# Vf                              NaN
# year                       0.043373
# Electric range (km)       66.666667
# #identical occurences    344.664041
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2019_536L4D-YV1-1: ID                       6.217427e+01
# r                        0.000000e+00
# m (kg)                   3.457658e-01
# Mt                       1.628028e+00
# Enedc (g/km)             1.325157e+00
# Ewltp (g/km)             1.724752e+00
# W (mm)                   9.371031e-02
# At1 (mm)                 2.700373e-02
# At2 (mm)                 1.032727e-01
# ec (cm3)                 1.968704e+00
# ep (KW)                  3.607834e+00
# z (Wh/km)                         NaN
# Ernedc (g/km)            4.810966e-13
# Erwltp (g/km)            9.816762e+00
# De                                NaN
# Vf                                NaN
# year                     4.906343e-02
# Electric range (km)               NaN
# #identical occurences    2.622151e+02
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2021_256H5D-YV1-1: ID                        24.551730
# r                          0.000000
# m (kg)                     0.764514
# Mt                         1.368215
# Enedc (g/km)               2.843589
# Ewltp (g/km)              88.413382
# W (mm)                     0.037564
# At1 (mm)                   0.945942
# At2 (mm)                   0.951738
# ec (cm3)                   0.000000
# ep (KW)                    8.177068
# z (Wh/km)                  4.392497
# Ernedc (g/km)                   NaN
# Erwltp (g/km)              0.000000
# De                              NaN
# Vf                              NaN
# year                       0.026401
# Electric range (km)        8.516295
# #identical occurences    266.139290
# dtype: float64
#
# Percentage error relative to the mean for 'VFN' = IP-2019_246K9D-YV1-1: ID                        48.815612
# r                          0.000000
# m (kg)                     1.186795
# Mt                         1.633128
# Enedc (g/km)               1.013658
# Ewltp (g/km)               3.536792
# W (mm)                     0.629678
# At1 (mm)                   2.709737
# At2 (mm)                   2.707316
# ec (cm3)                   0.000000
# ep (KW)                    1.648418
# z (Wh/km)                       NaN
# Ernedc (g/km)              9.748703
# Erwltp (g/km)              7.577916
# De                              NaN
# Vf                              NaN
# year                       0.044418
# Electric range (km)        0.000000
# #identical occurences    353.613950
# dtype: float64

# %% [markdown]
# Ve scheint wohl laut chat die VIN bzw fahrzeug identifikations nummer zu sein

# %% [markdown]
# Now, lass uns mal danach suchen wie groß die varianz der anderen variablen columns bei einheitlichen
# VINs bzw VEs ist

# %% [markdown]
# Wichtig: hier sieht man das nach dem filtern nur noch 56.000 spalten übrig bleiben, was bei den anderen ist
# .. ka

# %% [markdown]
# # Begin filtering for duplicates in TAN

# %% [markdown]
# # Begin filtering for duplicates VFN

# %% [markdown]
# ## Takeaway To-Dos from Group Meeting:
#
# - Make My own data frame
# - Take only data that contains EWltp values
# - Take only data year = 2016 and younger (2017 , 2018...)
# - Look for duplicates in the Type variables called: TVV, VHF, TAN
# - look for varianze among same of these type variables of the other variables
#
# - if there is one that has minimum varianz -> take that and unify these
# - make new variable called appearance in EU data, or R
#
# -> that would be my EU_Dataframe

# %% [markdown]
# # Next Possible Working steps
#
# Filter out all data that has no explanatory variable
#
# Filter out all data that is later then 2015 oder wann auch immer diese EU gesetzes änderung und der Gas Skandal war
# (siehe Report)
#
# Try to find eindeutige Beschreibungs nummer eines autos
#
# Try to find overlay with the Adame Data Frame
#
# Immer noch die Frage wo ist der Entscheidenden Punkt der Correlation ?
#
# Hier nochmal danach eine Correlation Maxtrix Ausgeben und Nochmal den Data Audit ansehen, was die Columns zu bedeuten haben
#
# Explore TVV Combination: Investigate whether we should combine the TVV (Type, Variant, Version) into a single variable, and decide on a common approach.
#
# Outlier Handling: Implement or refine outlier detection and removal in the dataset, ensuring it's properly applied across notebooks.
#
# Analyze the 'R' Column: Further explore the "R" column, especially for values after 2020 where all "R" values equal one. Include this for discussion in the next meeting.
